# %% [markdown]
# # Read actors File

# %%
import pandas as pd
from os.path import exists
import glob
actors = pd.read_csv('../files/actorsOrig.csv', header=0)

# %% [markdown]
# # Apply Filters

# %%
print("Actor Count before Filter:",len(actors))
actors = actors.reset_index(drop=True)
print(len(actors))
actors.head()
# Out:
# Actor Count before Filter: 57041
# 57041
#       nconst       primaryName     tconst
# 0  nm0000004      John Belushi  tt0077621
# 1  nm0005460  Mary Steenburgen  tt0077621
# 2  nm0000004      John Belushi  tt0077975
# 3  nm0000261       Karen Allen  tt0077975
# 4  nm0001371         Tom Hulce  tt0077975

# %% [markdown]
# # Check Samples

# %% [markdown]
# # Get Unique Titles for Actors

# %%
uniqTitlesList = list(set(actors['tconst']))
uniqTitlesList.sort()
print(len(uniqTitlesList))
# Out:
# 18657

# %% [markdown]
# # Scrape Related Fuctions

# %%
from bs4 import BeautifulSoup
from selenium import webdriver 
from selenium.webdriver.chrome.options import Options
import re 
import urllib
import time

# %%
#create a webdriver object and set options for headless browsing
options = Options()
options.headless = True
driver = webdriver.Chrome('../chromedriver',options=options)

# %%
#uses webdriver object to execute javascript code and get dynamically loaded webcontent
def get_js_soup(url,driver):
    driver.get(url)
    res_html = driver.execute_script('return document.body.innerHTML')
    soup = BeautifulSoup(res_html,'html.parser') #beautiful soup object to be used for parsing html content
    return soup

#tidies extracted text 
def process_mov(mov):
    mov = mov.encode('ascii',errors='ignore').decode('utf-8')       #removes non-ascii characters
    mov = re.sub('\s+',' ',mov)       #repalces repeated whitespace characters with single space
    return mov

''' More tidying
Sometimes the text extracted HTML webpage may contain javascript code and some style elements. 
This function removes script and style tags from HTML so that extracted text does not contain them.
'''
def remove_script(soup):
    for script in soup(["script", "style"]):
        script.decompose()
    return soup


#Checks if bio_url is a valid faculty homepage
def is_valid_homepage(mov_url,dir_url):
    if mov_url.endswith('.pdf'): #we're not parsing pdfs
        return False
    try:
        #sometimes the homepage url points to the same page as the faculty profile page
        #which should be treated differently from an actual homepage
        ret_url = urllib.request.urlopen(mov_url).geturl() 
    except:
        return False       #unable to access bio_url
    urls = [re.sub('((https?://)|(www.))','',url) for url in [ret_url,dir_url]] #removes url scheme (https,http or www) 
    return not(urls[0]== urls[1])

def scrape_movie_page(mov_url,driver):
    soup = get_js_soup(mov_url,driver)
    homepage_found = False
    #profile_sec = soup.find('section',class_='main-content')
    profile_sec = soup.find('section',class_='article listo')
    if profile_sec == None:
        mov = ''
        print("Skipping mov : ",mov_url)
    else:
        mov = process_mov(profile_sec.get_text(separator=' '))
    return mov_url,mov

# %%
def write_lst(lst,file_):
    lst = lst.replace(' Plot Showing all 0 items Jump to: ','')
    lst = lst.replace(' Plot Showing all 1 items Jump to: Summaries (1) ','')
    lst = lst.replace(' Plot Showing all 2 items Jump to: Summaries (2) ','')
    lst = lst.replace(' Plot Showing all 3 items Jump to: Summaries (3) ','')
    lst = lst.replace(' Plot Showing all ','').replace(' items Jump to: Summaries (','')
    lst = lst.replace(') Synopsis (','').replace(' Synopsis','').replace(' Summaries','')
    lst = lst.replace('Edit ','')

    with open(file_,'w') as f:
        f.write(lst)

# %% [markdown]
# # Scrape Movie plot summary and store in "movieFile" dir
#
# - Skip already processed files in case of a Restart

# %%
fileList = glob.glob("../movieFile/*.txt")
fileListVals = []
for i in fileList:
    fileListVals.append(int(i.replace('../movieFile/','').replace('.txt','').replace('tt','')))
    
print(len(fileListVals),max(fileListVals))
    

if len(fileList) <= 0:
    last_scraped = 0
else:
    last_scraped = (max(fileListVals))


uniqTitlesInt = sorted(int(i.replace('tt','')) for i in uniqTitlesList if int(i.replace('tt','')) > last_scraped)

uniqTitles = []
for i in uniqTitlesInt:
    uniqTitles.append('tt'+str(i))
    
print('tt' + str(last_scraped))
print(len(uniqTitles))
# Out:
# 8813 9916362
# tt9916362
# 490

# %%
#Scrape homepages of all urls
tot_urls = len(uniqTitles)
for i,l in enumerate(uniqTitles):
    link="https://www.imdb.com/title/"+l+"/plotsummary"
    print ('-'*20,'Scraping movie url {}/{}'.format(i+1,tot_urls),'-'*20)
    print(link)
    mov_urls, movs = [],[]
    mov_url,mov = scrape_movie_page(link,driver)
    if len(mov) < 2000:
        print("SKIPPING")
    else:
        if mov.strip()!= '' and mov_url.strip()!='':
            mov_file = '../movieFile/'+l+'.txt'
            write_lst(mov,mov_file)
driver.close()
# Out:
# -------------------- Scraping movie url 1/490 --------------------
# https://www.imdb.com/title/tt10003008/plotsummary
# -------------------- Scraping movie url 2/490 --------------------
# https://www.imdb.com/title/tt10006006/plotsummary
# SKIPPING
# -------------------- Scraping movie url 3/490 --------------------
# https://www.imdb.com/title/tt10008784/plotsummary
# SKIPPING
# -------------------- Scraping movie url 4/490 --------------------
# https://www.imdb.com/title/tt10009030/plotsummary
# SKIPPING
# -------------------- Scraping movie url 5/490 --------------------
# https://www.imdb.com/title/tt10016180/plotsummary
# -------------------- Scraping movie url 6/490 --------------------
# https://www.imdb.com/title/tt10023024/plotsummary
# SKIPPING
# -------------------- Scraping movie url 7/490 --------------------
# https://www.imdb.com/title/tt10037014/plotsummary
# SKIPPING
# -------------------- Scraping movie url 8/490 --------------------
# https://www.imdb.com/title/tt10039344/plotsummary
# -------------------- Scraping movie url 9/490 --------------------
# https://www.imdb.com/title/tt10045434/plotsummary
# SKIPPING
# -------------------- Scraping movie url 10/490 --------------------
# https://www.imdb.com/title/tt10047958/plotsummary
# SKIPPING
# -------------------- Scraping movie url 11/490 --------------------
# https://www.imdb.com/title/tt10059518/plotsummary
# -------------------- Scraping movie url 12/490 --------------------
# https://www.imdb.com/title/tt10060094/plotsummary
# SKIPPING
# -------------------- Scraping movie url 13/490 --------------------
# https://www.imdb.com/title/tt10062556/plotsummary
# -------------------- Scraping movie url 14/490 --------------------
# https://www.imdb.com/title/tt10062614/plotsummary
# SKIPPING
# -------------------- Scraping movie url 15/490 --------------------
# https://www.imdb.com/title/tt10065694/plotsummary
# -------------------- Scraping movie url 16/490 --------------------
# https://www.imdb.com/title/tt10068916/plotsummary
# SKIPPING
# -------------------- Scraping movie url 17/490 --------------------
# https://www.imdb.com/title/tt10077034/plotsummary
# SKIPPING
# -------------------- Scraping movie url 18/490 --------------------
# https://www.imdb.com/title/tt10081762/plotsummary
# SKIPPING
# -------------------- Scraping movie url 19/490 --------------------
# https://www.imdb.com/title/tt10083640/plotsummary
# SKIPPING
# -------------------- Scraping movie url 20/490 --------------------
# https://www.imdb.com/title/tt10084190/plotsummary
# SKIPPING
# -------------------- Scraping movie url 21/490 --------------------
# https://www.imdb.com/title/tt10091530/plotsummary
# SKIPPING
# -------------------- Scraping movie url 22/490 --------------------
# https://www.imdb.com/title/tt10092752/plotsummary
# SKIPPING
# -------------------- Scraping movie url 23/490 --------------------
# https://www.imdb.com/title/tt10096842/plotsummary
# SKIPPING
# -------------------- Scraping movie url 24/490 --------------------
# https://www.imdb.com/title/tt10098288/plotsummary
# SKIPPING
# -------------------- Scraping movie url 25/490 --------------------
# https://www.imdb.com/title/tt10101702/plotsummary
# SKIPPING
# -------------------- Scraping movie url 26/490 --------------------
# https://www.imdb.com/title/tt10110614/plotsummary
# SKIPPING
# -------------------- Scraping movie url 27/490 --------------------
# https://www.imdb.com/title/tt10121392/plotsummary
# SKIPPING
# -------------------- Scraping movie url 28/490 --------------------
# https://www.imdb.com/title/tt10126434/plotsummary
# -------------------- Scraping movie url 29/490 --------------------
# https://www.imdb.com/title/tt10127562/plotsummary
# SKIPPING
# -------------------- Scraping movie url 30/490 --------------------
# https://www.imdb.com/title/tt10127684/plotsummary
# SKIPPING
# -------------------- Scraping movie url 31/490 --------------------
# https://www.imdb.com/title/tt10148118/plotsummary
# SKIPPING
# -------------------- Scraping movie url 32/490 --------------------
# https://www.imdb.com/title/tt10149868/plotsummary
# SKIPPING
# -------------------- Scraping movie url 33/490 --------------------
# https://www.imdb.com/title/tt10151054/plotsummary
# SKIPPING
# -------------------- Scraping movie url 34/490 --------------------
# https://www.imdb.com/title/tt10151260/plotsummary
# SKIPPING
# -------------------- Scraping movie url 35/490 --------------------
# https://www.imdb.com/title/tt10152736/plotsummary
# SKIPPING
# -------------------- Scraping movie url 36/490 --------------------
# https://www.imdb.com/title/tt10155932/plotsummary
# SKIPPING
# -------------------- Scraping movie url 37/490 --------------------
# https://www.imdb.com/title/tt10161886/plotsummary
# SKIPPING
# -------------------- Scraping movie url 38/490 --------------------
# https://www.imdb.com/title/tt10182822/plotsummary
# SKIPPING
# -------------------- Scraping movie url 39/490 --------------------
# https://www.imdb.com/title/tt10183816/plotsummary
# SKIPPING
# -------------------- Scraping movie url 40/490 --------------------
# https://www.imdb.com/title/tt10187680/plotsummary
# SKIPPING
# -------------------- Scraping movie url 41/490 --------------------
# https://www.imdb.com/title/tt10189514/plotsummary
# SKIPPING
# -------------------- Scraping movie url 42/490 --------------------
# https://www.imdb.com/title/tt10192566/plotsummary
# SKIPPING
# -------------------- Scraping movie url 43/490 --------------------
# https://www.imdb.com/title/tt10192704/plotsummary
# SKIPPING
# -------------------- Scraping movie url 44/490 --------------------
# https://www.imdb.com/title/tt10195452/plotsummary
# SKIPPING
# -------------------- Scraping movie url 45/490 --------------------
# https://www.imdb.com/title/tt10196398/plotsummary
# SKIPPING
# -------------------- Scraping movie url 46/490 --------------------
# https://www.imdb.com/title/tt10196464/plotsummary
# SKIPPING
# -------------------- Scraping movie url 47/490 --------------------
# https://www.imdb.com/title/tt10199590/plotsummary
# -------------------- Scraping movie url 48/490 --------------------
# https://www.imdb.com/title/tt10199914/plotsummary
# SKIPPING
# -------------------- Scraping movie url 49/490 --------------------
# https://www.imdb.com/title/tt10204940/plotsummary
# SKIPPING
# -------------------- Scraping movie url 50/490 --------------------
# https://www.imdb.com/title/tt10208198/plotsummary
# -------------------- Scraping movie url 51/490 --------------------
# https://www.imdb.com/title/tt10217550/plotsummary
# SKIPPING
# -------------------- Scraping movie url 52/490 --------------------
# https://www.imdb.com/title/tt10228134/plotsummary
# -------------------- Scraping movie url 53/490 --------------------
# https://www.imdb.com/title/tt10228168/plotsummary
# -------------------- Scraping movie url 54/490 --------------------
# https://www.imdb.com/title/tt10229558/plotsummary
# SKIPPING
# -------------------- Scraping movie url 55/490 --------------------
# https://www.imdb.com/title/tt10230404/plotsummary
# SKIPPING
# -------------------- Scraping movie url 56/490 --------------------
# https://www.imdb.com/title/tt10230414/plotsummary
# SKIPPING
# -------------------- Scraping movie url 57/490 --------------------
# https://www.imdb.com/title/tt10230422/plotsummary
# SKIPPING
# -------------------- Scraping movie url 58/490 --------------------
# https://www.imdb.com/title/tt10230426/plotsummary
# SKIPPING
# -------------------- Scraping movie url 59/490 --------------------
# https://www.imdb.com/title/tt10230994/plotsummary
# -------------------- Scraping movie url 60/490 --------------------
# https://www.imdb.com/title/tt10243678/plotsummary
# SKIPPING
# -------------------- Scraping movie url 61/490 --------------------
# https://www.imdb.com/title/tt10243992/plotsummary
# -------------------- Scraping movie url 62/490 --------------------
# https://www.imdb.com/title/tt10247678/plotsummary
# SKIPPING
# -------------------- Scraping movie url 63/490 --------------------
# https://www.imdb.com/title/tt10253466/plotsummary
# SKIPPING
# -------------------- Scraping movie url 64/490 --------------------
# https://www.imdb.com/title/tt10263320/plotsummary
# SKIPPING
# -------------------- Scraping movie url 65/490 --------------------
# https://www.imdb.com/title/tt10265034/plotsummary
# SKIPPING
# -------------------- Scraping movie url 66/490 --------------------
# https://www.imdb.com/title/tt10272386/plotsummary
# -------------------- Scraping movie url 67/490 --------------------
# https://www.imdb.com/title/tt10272534/plotsummary
# SKIPPING
# -------------------- Scraping movie url 68/490 --------------------
# https://www.imdb.com/title/tt10274284/plotsummary
# -------------------- Scraping movie url 69/490 --------------------
# https://www.imdb.com/title/tt10276470/plotsummary
# SKIPPING
# -------------------- Scraping movie url 70/490 --------------------
# https://www.imdb.com/title/tt10279362/plotsummary
# SKIPPING
# -------------------- Scraping movie url 71/490 --------------------
# https://www.imdb.com/title/tt10280276/plotsummary
# SKIPPING
# -------------------- Scraping movie url 72/490 --------------------
# https://www.imdb.com/title/tt10280296/plotsummary
# SKIPPING
# -------------------- Scraping movie url 73/490 --------------------
# https://www.imdb.com/title/tt10283902/plotsummary
# SKIPPING
# -------------------- Scraping movie url 74/490 --------------------
# https://www.imdb.com/title/tt10287954/plotsummary
# SKIPPING
# -------------------- Scraping movie url 75/490 --------------------
# https://www.imdb.com/title/tt10288566/plotsummary
# -------------------- Scraping movie url 76/490 --------------------
# https://www.imdb.com/title/tt10293406/plotsummary
# SKIPPING
# -------------------- Scraping movie url 77/490 --------------------
# https://www.imdb.com/title/tt10295212/plotsummary
# -------------------- Scraping movie url 78/490 --------------------
# https://www.imdb.com/title/tt10303324/plotsummary
# SKIPPING
# -------------------- Scraping movie url 79/490 --------------------
# https://www.imdb.com/title/tt10303430/plotsummary
# -------------------- Scraping movie url 80/490 --------------------
# https://www.imdb.com/title/tt10307440/plotsummary
# SKIPPING
# -------------------- Scraping movie url 81/490 --------------------
# https://www.imdb.com/title/tt10307724/plotsummary
# SKIPPING
# -------------------- Scraping movie url 82/490 --------------------
# https://www.imdb.com/title/tt10308928/plotsummary
# -------------------- Scraping movie url 83/490 --------------------
# https://www.imdb.com/title/tt10309552/plotsummary
# -------------------- Scraping movie url 84/490 --------------------
# https://www.imdb.com/title/tt10309902/plotsummary
# -------------------- Scraping movie url 85/490 --------------------
# https://www.imdb.com/title/tt10309906/plotsummary
# SKIPPING
# -------------------- Scraping movie url 86/490 --------------------
# https://www.imdb.com/title/tt10310140/plotsummary
# SKIPPING
# -------------------- Scraping movie url 87/490 --------------------
# https://www.imdb.com/title/tt10314450/plotsummary
# -------------------- Scraping movie url 88/490 --------------------
# https://www.imdb.com/title/tt10319486/plotsummary
# SKIPPING
# -------------------- Scraping movie url 89/490 --------------------
# https://www.imdb.com/title/tt10320050/plotsummary
# SKIPPING
# -------------------- Scraping movie url 90/490 --------------------
# https://www.imdb.com/title/tt10324122/plotsummary
# SKIPPING
# -------------------- Scraping movie url 91/490 --------------------
# https://www.imdb.com/title/tt10324144/plotsummary
# SKIPPING
# -------------------- Scraping movie url 92/490 --------------------
# https://www.imdb.com/title/tt10327252/plotsummary
# -------------------- Scraping movie url 93/490 --------------------
# https://www.imdb.com/title/tt10329134/plotsummary
# -------------------- Scraping movie url 94/490 --------------------
# https://www.imdb.com/title/tt10329566/plotsummary
# SKIPPING
# -------------------- Scraping movie url 95/490 --------------------
# https://www.imdb.com/title/tt10329614/plotsummary
# SKIPPING
# -------------------- Scraping movie url 96/490 --------------------
# https://www.imdb.com/title/tt10329842/plotsummary
# SKIPPING
# -------------------- Scraping movie url 97/490 --------------------
# https://www.imdb.com/title/tt10332588/plotsummary
# SKIPPING
# -------------------- Scraping movie url 98/490 --------------------
# https://www.imdb.com/title/tt10333426/plotsummary
# SKIPPING
# -------------------- Scraping movie url 99/490 --------------------
# https://www.imdb.com/title/tt10333912/plotsummary
# SKIPPING
# -------------------- Scraping movie url 100/490 --------------------
# https://www.imdb.com/title/tt10334148/plotsummary
# SKIPPING
# -------------------- Scraping movie url 101/490 --------------------
# https://www.imdb.com/title/tt10342228/plotsummary
# SKIPPING
# -------------------- Scraping movie url 102/490 --------------------
# https://www.imdb.com/title/tt10342730/plotsummary
# -------------------- Scraping movie url 103/490 --------------------
# https://www.imdb.com/title/tt10344522/plotsummary
# SKIPPING
# -------------------- Scraping movie url 104/490 --------------------
# https://www.imdb.com/title/tt10345590/plotsummary
# SKIPPING
# -------------------- Scraping movie url 105/490 --------------------
# https://www.imdb.com/title/tt10350626/plotsummary
# SKIPPING
# -------------------- Scraping movie url 106/490 --------------------
# https://www.imdb.com/title/tt10350922/plotsummary
# SKIPPING
# -------------------- Scraping movie url 107/490 --------------------
# https://www.imdb.com/title/tt10358198/plotsummary
# -------------------- Scraping movie url 108/490 --------------------
# https://www.imdb.com/title/tt10360862/plotsummary
# SKIPPING
# -------------------- Scraping movie url 109/490 --------------------
# https://www.imdb.com/title/tt10362466/plotsummary
# SKIPPING
# -------------------- Scraping movie url 110/490 --------------------
# https://www.imdb.com/title/tt10366460/plotsummary
# -------------------- Scraping movie url 111/490 --------------------
# https://www.imdb.com/title/tt10370380/plotsummary
# SKIPPING
# -------------------- Scraping movie url 112/490 --------------------
# https://www.imdb.com/title/tt10370710/plotsummary
# SKIPPING
# -------------------- Scraping movie url 113/490 --------------------
# https://www.imdb.com/title/tt10375106/plotsummary
# SKIPPING
# -------------------- Scraping movie url 114/490 --------------------
# https://www.imdb.com/title/tt10384744/plotsummary
# -------------------- Scraping movie url 115/490 --------------------
# https://www.imdb.com/title/tt10404944/plotsummary
# SKIPPING
# -------------------- Scraping movie url 116/490 --------------------
# https://www.imdb.com/title/tt10407272/plotsummary
# SKIPPING
# -------------------- Scraping movie url 117/490 --------------------
# https://www.imdb.com/title/tt10409498/plotsummary
# SKIPPING
# -------------------- Scraping movie url 118/490 --------------------
# https://www.imdb.com/title/tt10413566/plotsummary
# SKIPPING
# -------------------- Scraping movie url 119/490 --------------------
# https://www.imdb.com/title/tt10418662/plotsummary
# SKIPPING
# -------------------- Scraping movie url 120/490 --------------------
# https://www.imdb.com/title/tt10428246/plotsummary
# SKIPPING
# -------------------- Scraping movie url 121/490 --------------------
# https://www.imdb.com/title/tt10431500/plotsummary
# SKIPPING
# -------------------- Scraping movie url 122/490 --------------------
# https://www.imdb.com/title/tt10441806/plotsummary
# SKIPPING
# -------------------- Scraping movie url 123/490 --------------------
# https://www.imdb.com/title/tt10451852/plotsummary
# -------------------- Scraping movie url 124/490 --------------------
# https://www.imdb.com/title/tt10451914/plotsummary
# -------------------- Scraping movie url 125/490 --------------------
# https://www.imdb.com/title/tt10456740/plotsummary
# SKIPPING
# -------------------- Scraping movie url 126/490 --------------------
# https://www.imdb.com/title/tt10457128/plotsummary
# SKIPPING
# -------------------- Scraping movie url 127/490 --------------------
# https://www.imdb.com/title/tt10463030/plotsummary
# SKIPPING
# -------------------- Scraping movie url 128/490 --------------------
# https://www.imdb.com/title/tt10468636/plotsummary
# SKIPPING
# -------------------- Scraping movie url 129/490 --------------------
# https://www.imdb.com/title/tt10472884/plotsummary
# SKIPPING
# -------------------- Scraping movie url 130/490 --------------------
# https://www.imdb.com/title/tt10477558/plotsummary
# SKIPPING
# -------------------- Scraping movie url 131/490 --------------------
# https://www.imdb.com/title/tt10481868/plotsummary
# -------------------- Scraping movie url 132/490 --------------------
# https://www.imdb.com/title/tt10482504/plotsummary
# SKIPPING
# -------------------- Scraping movie url 133/490 --------------------
# https://www.imdb.com/title/tt10483386/plotsummary
# SKIPPING
# -------------------- Scraping movie url 134/490 --------------------
# https://www.imdb.com/title/tt10492998/plotsummary
# SKIPPING
# -------------------- Scraping movie url 135/490 --------------------
# https://www.imdb.com/title/tt10508838/plotsummary
# SKIPPING
# -------------------- Scraping movie url 136/490 --------------------
# https://www.imdb.com/title/tt10514222/plotsummary
# -------------------- Scraping movie url 137/490 --------------------
# https://www.imdb.com/title/tt10515086/plotsummary
# SKIPPING
# -------------------- Scraping movie url 138/490 --------------------
# https://www.imdb.com/title/tt10515526/plotsummary
# SKIPPING
# -------------------- Scraping movie url 139/490 --------------------
# https://www.imdb.com/title/tt10515988/plotsummary
# SKIPPING
# -------------------- Scraping movie url 140/490 --------------------
# https://www.imdb.com/title/tt10521092/plotsummary
# SKIPPING
# -------------------- Scraping movie url 141/490 --------------------
# https://www.imdb.com/title/tt10521144/plotsummary
# SKIPPING
# -------------------- Scraping movie url 142/490 --------------------
# https://www.imdb.com/title/tt10521814/plotsummary
# SKIPPING
# -------------------- Scraping movie url 143/490 --------------------
# https://www.imdb.com/title/tt10525672/plotsummary
# SKIPPING
# -------------------- Scraping movie url 144/490 --------------------
# https://www.imdb.com/title/tt10530176/plotsummary
# -------------------- Scraping movie url 145/490 --------------------
# https://www.imdb.com/title/tt10539608/plotsummary
# -------------------- Scraping movie url 146/490 --------------------
# https://www.imdb.com/title/tt10540242/plotsummary
# SKIPPING
# -------------------- Scraping movie url 147/490 --------------------
# https://www.imdb.com/title/tt10543680/plotsummary
# SKIPPING
# -------------------- Scraping movie url 148/490 --------------------
# https://www.imdb.com/title/tt10545484/plotsummary
# SKIPPING
# -------------------- Scraping movie url 149/490 --------------------
# https://www.imdb.com/title/tt10550884/plotsummary
# SKIPPING
# -------------------- Scraping movie url 150/490 --------------------
# https://www.imdb.com/title/tt10554232/plotsummary
# SKIPPING
# -------------------- Scraping movie url 151/490 --------------------
# https://www.imdb.com/title/tt10556022/plotsummary
# SKIPPING
# -------------------- Scraping movie url 152/490 --------------------
# https://www.imdb.com/title/tt10579952/plotsummary
# SKIPPING
# -------------------- Scraping movie url 153/490 --------------------
# https://www.imdb.com/title/tt10589914/plotsummary
# -------------------- Scraping movie url 154/490 --------------------
# https://www.imdb.com/title/tt10600398/plotsummary
# SKIPPING
# -------------------- Scraping movie url 155/490 --------------------
# https://www.imdb.com/title/tt10605812/plotsummary
# SKIPPING
# -------------------- Scraping movie url 156/490 --------------------
# https://www.imdb.com/title/tt10611372/plotsummary
# SKIPPING
# -------------------- Scraping movie url 157/490 --------------------
# https://www.imdb.com/title/tt10612922/plotsummary
# SKIPPING
# -------------------- Scraping movie url 158/490 --------------------
# https://www.imdb.com/title/tt10618286/plotsummary
# -------------------- Scraping movie url 159/490 --------------------
# https://www.imdb.com/title/tt10620868/plotsummary
# SKIPPING
# -------------------- Scraping movie url 160/490 --------------------
# https://www.imdb.com/title/tt10621032/plotsummary
# SKIPPING
# -------------------- Scraping movie url 161/490 --------------------
# https://www.imdb.com/title/tt10627548/plotsummary
# SKIPPING
# -------------------- Scraping movie url 162/490 --------------------
# https://www.imdb.com/title/tt10627584/plotsummary
# SKIPPING
# -------------------- Scraping movie url 163/490 --------------------
# https://www.imdb.com/title/tt10633456/plotsummary
# -------------------- Scraping movie url 164/490 --------------------
# https://www.imdb.com/title/tt10644282/plotsummary
# SKIPPING
# -------------------- Scraping movie url 165/490 --------------------
# https://www.imdb.com/title/tt10648440/plotsummary
# SKIPPING
# -------------------- Scraping movie url 166/490 --------------------
# https://www.imdb.com/title/tt10648714/plotsummary
# SKIPPING
# -------------------- Scraping movie url 167/490 --------------------
# https://www.imdb.com/title/tt10661710/plotsummary
# SKIPPING
# -------------------- Scraping movie url 168/490 --------------------
# https://www.imdb.com/title/tt10661848/plotsummary
# SKIPPING
# -------------------- Scraping movie url 169/490 --------------------
# https://www.imdb.com/title/tt10665338/plotsummary
# -------------------- Scraping movie url 170/490 --------------------
# https://www.imdb.com/title/tt10675724/plotsummary
# SKIPPING
# -------------------- Scraping movie url 171/490 --------------------
# https://www.imdb.com/title/tt10676012/plotsummary
# -------------------- Scraping movie url 172/490 --------------------
# https://www.imdb.com/title/tt10682266/plotsummary
# -------------------- Scraping movie url 173/490 --------------------
# https://www.imdb.com/title/tt10687506/plotsummary
# SKIPPING
# -------------------- Scraping movie url 174/490 --------------------
# https://www.imdb.com/title/tt10691162/plotsummary
# SKIPPING
# -------------------- Scraping movie url 175/490 --------------------
# https://www.imdb.com/title/tt10696784/plotsummary
# -------------------- Scraping movie url 176/490 --------------------
# https://www.imdb.com/title/tt10696896/plotsummary
# -------------------- Scraping movie url 177/490 --------------------
# https://www.imdb.com/title/tt10702148/plotsummary
# SKIPPING
# -------------------- Scraping movie url 178/490 --------------------
# https://www.imdb.com/title/tt10702760/plotsummary
# SKIPPING
# -------------------- Scraping movie url 179/490 --------------------
# https://www.imdb.com/title/tt10710246/plotsummary
# SKIPPING
# -------------------- Scraping movie url 180/490 --------------------
# https://www.imdb.com/title/tt10711648/plotsummary
# SKIPPING
# -------------------- Scraping movie url 181/490 --------------------
# https://www.imdb.com/title/tt10714856/plotsummary
# SKIPPING
# -------------------- Scraping movie url 182/490 --------------------
# https://www.imdb.com/title/tt10717738/plotsummary
# SKIPPING
# -------------------- Scraping movie url 183/490 --------------------
# https://www.imdb.com/title/tt10728764/plotsummary
# SKIPPING
# -------------------- Scraping movie url 184/490 --------------------
# https://www.imdb.com/title/tt10731264/plotsummary
# SKIPPING
# -------------------- Scraping movie url 185/490 --------------------
# https://www.imdb.com/title/tt10731748/plotsummary
# SKIPPING
# -------------------- Scraping movie url 186/490 --------------------
# https://www.imdb.com/title/tt10731768/plotsummary
# -------------------- Scraping movie url 187/490 --------------------
# https://www.imdb.com/title/tt10736580/plotsummary
# SKIPPING
# -------------------- Scraping movie url 188/490 --------------------
# https://www.imdb.com/title/tt10741542/plotsummary
# SKIPPING
# -------------------- Scraping movie url 189/490 --------------------
# https://www.imdb.com/title/tt10752004/plotsummary
# SKIPPING
# -------------------- Scraping movie url 190/490 --------------------
# https://www.imdb.com/title/tt10756374/plotsummary
# SKIPPING
# -------------------- Scraping movie url 191/490 --------------------
# https://www.imdb.com/title/tt10763618/plotsummary
# SKIPPING
# -------------------- Scraping movie url 192/490 --------------------
# https://www.imdb.com/title/tt10763820/plotsummary
# SKIPPING
# -------------------- Scraping movie url 193/490 --------------------
# https://www.imdb.com/title/tt10767426/plotsummary
# SKIPPING
# -------------------- Scraping movie url 194/490 --------------------
# https://www.imdb.com/title/tt10772662/plotsummary
# SKIPPING
# -------------------- Scraping movie url 195/490 --------------------
# https://www.imdb.com/title/tt10773090/plotsummary
# SKIPPING
# -------------------- Scraping movie url 196/490 --------------------
# https://www.imdb.com/title/tt10778840/plotsummary
# SKIPPING
# -------------------- Scraping movie url 197/490 --------------------
# https://www.imdb.com/title/tt10796286/plotsummary
# SKIPPING
# -------------------- Scraping movie url 198/490 --------------------
# https://www.imdb.com/title/tt10805432/plotsummary
# -------------------- Scraping movie url 199/490 --------------------
# https://www.imdb.com/title/tt10808832/plotsummary
# SKIPPING
# -------------------- Scraping movie url 200/490 --------------------
# https://www.imdb.com/title/tt10816484/plotsummary
# SKIPPING
# -------------------- Scraping movie url 201/490 --------------------
# https://www.imdb.com/title/tt10831086/plotsummary
# -------------------- Scraping movie url 202/490 --------------------
# https://www.imdb.com/title/tt10843306/plotsummary
# SKIPPING
# -------------------- Scraping movie url 203/490 --------------------
# https://www.imdb.com/title/tt10883302/plotsummary
# SKIPPING
# -------------------- Scraping movie url 204/490 --------------------
# https://www.imdb.com/title/tt10883506/plotsummary
# SKIPPING
# -------------------- Scraping movie url 205/490 --------------------
# https://www.imdb.com/title/tt10885444/plotsummary
# SKIPPING
# -------------------- Scraping movie url 206/490 --------------------
# https://www.imdb.com/title/tt10886166/plotsummary
# -------------------- Scraping movie url 207/490 --------------------
# https://www.imdb.com/title/tt10887902/plotsummary
# SKIPPING
# -------------------- Scraping movie url 208/490 --------------------
# https://www.imdb.com/title/tt10888594/plotsummary
# SKIPPING
# -------------------- Scraping movie url 209/490 --------------------
# https://www.imdb.com/title/tt10888708/plotsummary
# SKIPPING
# -------------------- Scraping movie url 210/490 --------------------
# https://www.imdb.com/title/tt10888824/plotsummary
# SKIPPING
# -------------------- Scraping movie url 211/490 --------------------
# https://www.imdb.com/title/tt10893170/plotsummary
# SKIPPING
# -------------------- Scraping movie url 212/490 --------------------
# https://www.imdb.com/title/tt10895556/plotsummary
# SKIPPING
# -------------------- Scraping movie url 213/490 --------------------
# https://www.imdb.com/title/tt10901588/plotsummary
# -------------------- Scraping movie url 214/490 --------------------
# https://www.imdb.com/title/tt10914452/plotsummary
# SKIPPING
# -------------------- Scraping movie url 215/490 --------------------
# https://www.imdb.com/title/tt10915060/plotsummary
# SKIPPING
# -------------------- Scraping movie url 216/490 --------------------
# https://www.imdb.com/title/tt10916102/plotsummary
# SKIPPING
# -------------------- Scraping movie url 217/490 --------------------
# https://www.imdb.com/title/tt10919132/plotsummary
# SKIPPING
# -------------------- Scraping movie url 218/490 --------------------
# https://www.imdb.com/title/tt10919240/plotsummary
# SKIPPING
# -------------------- Scraping movie url 219/490 --------------------
# https://www.imdb.com/title/tt10919380/plotsummary
# -------------------- Scraping movie url 220/490 --------------------
# https://www.imdb.com/title/tt10920190/plotsummary
# SKIPPING
# -------------------- Scraping movie url 221/490 --------------------
# https://www.imdb.com/title/tt10930586/plotsummary
# SKIPPING
# -------------------- Scraping movie url 222/490 --------------------
# https://www.imdb.com/title/tt10933680/plotsummary
# SKIPPING
# -------------------- Scraping movie url 223/490 --------------------
# https://www.imdb.com/title/tt10937434/plotsummary
# SKIPPING
# -------------------- Scraping movie url 224/490 --------------------
# https://www.imdb.com/title/tt10941528/plotsummary
# SKIPPING
# -------------------- Scraping movie url 225/490 --------------------
# https://www.imdb.com/title/tt10944486/plotsummary
# -------------------- Scraping movie url 226/490 --------------------
# https://www.imdb.com/title/tt10944596/plotsummary
# SKIPPING
# -------------------- Scraping movie url 227/490 --------------------
# https://www.imdb.com/title/tt10944760/plotsummary
# -------------------- Scraping movie url 228/490 --------------------
# https://www.imdb.com/title/tt10948718/plotsummary
# SKIPPING
# -------------------- Scraping movie url 229/490 --------------------
# https://www.imdb.com/title/tt10949778/plotsummary
# SKIPPING
# -------------------- Scraping movie url 230/490 --------------------
# https://www.imdb.com/title/tt10952782/plotsummary
# -------------------- Scraping movie url 231/490 --------------------
# https://www.imdb.com/title/tt10954652/plotsummary
# -------------------- Scraping movie url 232/490 --------------------
# https://www.imdb.com/title/tt10955148/plotsummary
# -------------------- Scraping movie url 233/490 --------------------
# https://www.imdb.com/title/tt10962368/plotsummary
# -------------------- Scraping movie url 234/490 --------------------
# https://www.imdb.com/title/tt10964430/plotsummary
# SKIPPING
# -------------------- Scraping movie url 235/490 --------------------
# https://www.imdb.com/title/tt10964468/plotsummary
# SKIPPING
# -------------------- Scraping movie url 236/490 --------------------
# https://www.imdb.com/title/tt10973118/plotsummary
# SKIPPING
# -------------------- Scraping movie url 237/490 --------------------
# https://www.imdb.com/title/tt10975604/plotsummary
# SKIPPING
# -------------------- Scraping movie url 238/490 --------------------
# https://www.imdb.com/title/tt10978398/plotsummary
# -------------------- Scraping movie url 239/490 --------------------
# https://www.imdb.com/title/tt10991188/plotsummary
# SKIPPING
# -------------------- Scraping movie url 240/490 --------------------
# https://www.imdb.com/title/tt10994688/plotsummary
# SKIPPING
# -------------------- Scraping movie url 241/490 --------------------
# https://www.imdb.com/title/tt11003218/plotsummary
# -------------------- Scraping movie url 242/490 --------------------
# https://www.imdb.com/title/tt11015214/plotsummary
# SKIPPING
# -------------------- Scraping movie url 243/490 --------------------
# https://www.imdb.com/title/tt11024272/plotsummary
# -------------------- Scraping movie url 244/490 --------------------
# https://www.imdb.com/title/tt11027830/plotsummary
# SKIPPING
# -------------------- Scraping movie url 245/490 --------------------
# https://www.imdb.com/title/tt11032374/plotsummary
# SKIPPING
# -------------------- Scraping movie url 246/490 --------------------
# https://www.imdb.com/title/tt11044858/plotsummary
# SKIPPING
# -------------------- Scraping movie url 247/490 --------------------
# https://www.imdb.com/title/tt11045422/plotsummary
# SKIPPING
# -------------------- Scraping movie url 248/490 --------------------
# https://www.imdb.com/title/tt11046300/plotsummary
# SKIPPING
# -------------------- Scraping movie url 249/490 --------------------
# https://www.imdb.com/title/tt11052808/plotsummary
# SKIPPING
# -------------------- Scraping movie url 250/490 --------------------
# https://www.imdb.com/title/tt11054164/plotsummary
# SKIPPING
# -------------------- Scraping movie url 251/490 --------------------
# https://www.imdb.com/title/tt11057594/plotsummary
# SKIPPING
# -------------------- Scraping movie url 252/490 --------------------
# https://www.imdb.com/title/tt11057644/plotsummary
# -------------------- Scraping movie url 253/490 --------------------
# https://www.imdb.com/title/tt11073148/plotsummary
# SKIPPING
# -------------------- Scraping movie url 254/490 --------------------
# https://www.imdb.com/title/tt11080108/plotsummary
# SKIPPING
# -------------------- Scraping movie url 255/490 --------------------
# https://www.imdb.com/title/tt11081050/plotsummary
# SKIPPING
# -------------------- Scraping movie url 256/490 --------------------
# https://www.imdb.com/title/tt11083552/plotsummary
# -------------------- Scraping movie url 257/490 --------------------
# https://www.imdb.com/title/tt11084896/plotsummary
# SKIPPING
# -------------------- Scraping movie url 258/490 --------------------
# https://www.imdb.com/title/tt11100856/plotsummary
# SKIPPING
# -------------------- Scraping movie url 259/490 --------------------
# https://www.imdb.com/title/tt11102314/plotsummary
# SKIPPING
# -------------------- Scraping movie url 260/490 --------------------
# https://www.imdb.com/title/tt11107074/plotsummary
# SKIPPING
# -------------------- Scraping movie url 261/490 --------------------
# https://www.imdb.com/title/tt11112526/plotsummary
# SKIPPING
# -------------------- Scraping movie url 262/490 --------------------
# https://www.imdb.com/title/tt11121664/plotsummary
# -------------------- Scraping movie url 263/490 --------------------
# https://www.imdb.com/title/tt11125620/plotsummary
# -------------------- Scraping movie url 264/490 --------------------
# https://www.imdb.com/title/tt11127256/plotsummary
# SKIPPING
# -------------------- Scraping movie url 265/490 --------------------
# https://www.imdb.com/title/tt11127690/plotsummary
# SKIPPING
# -------------------- Scraping movie url 266/490 --------------------
# https://www.imdb.com/title/tt11140488/plotsummary
# SKIPPING
# -------------------- Scraping movie url 267/490 --------------------
# https://www.imdb.com/title/tt11142762/plotsummary
# SKIPPING
# -------------------- Scraping movie url 268/490 --------------------
# https://www.imdb.com/title/tt11161374/plotsummary
# SKIPPING
# -------------------- Scraping movie url 269/490 --------------------
# https://www.imdb.com/title/tt11161474/plotsummary
# -------------------- Scraping movie url 270/490 --------------------
# https://www.imdb.com/title/tt11169050/plotsummary
# SKIPPING
# -------------------- Scraping movie url 271/490 --------------------
# https://www.imdb.com/title/tt11176322/plotsummary
# SKIPPING
# -------------------- Scraping movie url 272/490 --------------------
# https://www.imdb.com/title/tt11188624/plotsummary
# -------------------- Scraping movie url 273/490 --------------------
# https://www.imdb.com/title/tt11196036/plotsummary
# -------------------- Scraping movie url 274/490 --------------------
# https://www.imdb.com/title/tt11199356/plotsummary
# SKIPPING
# -------------------- Scraping movie url 275/490 --------------------
# https://www.imdb.com/title/tt11199410/plotsummary
# SKIPPING
# -------------------- Scraping movie url 276/490 --------------------
# https://www.imdb.com/title/tt11213372/plotsummary
# SKIPPING
# -------------------- Scraping movie url 277/490 --------------------
# https://www.imdb.com/title/tt11213600/plotsummary
# SKIPPING
# -------------------- Scraping movie url 278/490 --------------------
# https://www.imdb.com/title/tt11229134/plotsummary
# SKIPPING
# -------------------- Scraping movie url 279/490 --------------------
# https://www.imdb.com/title/tt11229780/plotsummary
# SKIPPING
# -------------------- Scraping movie url 280/490 --------------------
# https://www.imdb.com/title/tt11231440/plotsummary
# SKIPPING
# -------------------- Scraping movie url 281/490 --------------------
# https://www.imdb.com/title/tt11235772/plotsummary
# SKIPPING
# -------------------- Scraping movie url 282/490 --------------------
# https://www.imdb.com/title/tt11240506/plotsummary
# SKIPPING
# -------------------- Scraping movie url 283/490 --------------------
# https://www.imdb.com/title/tt11242218/plotsummary
# SKIPPING
# -------------------- Scraping movie url 284/490 --------------------
# https://www.imdb.com/title/tt11250720/plotsummary
# SKIPPING
# -------------------- Scraping movie url 285/490 --------------------
# https://www.imdb.com/title/tt11253090/plotsummary
# SKIPPING
# -------------------- Scraping movie url 286/490 --------------------
# https://www.imdb.com/title/tt11260832/plotsummary
# -------------------- Scraping movie url 287/490 --------------------
# https://www.imdb.com/title/tt11263022/plotsummary
# SKIPPING
# -------------------- Scraping movie url 288/490 --------------------
# https://www.imdb.com/title/tt11266868/plotsummary
# SKIPPING
# -------------------- Scraping movie url 289/490 --------------------
# https://www.imdb.com/title/tt11274100/plotsummary
# SKIPPING
# -------------------- Scraping movie url 290/490 --------------------
# https://www.imdb.com/title/tt11276598/plotsummary
# SKIPPING
# -------------------- Scraping movie url 291/490 --------------------
# https://www.imdb.com/title/tt11284280/plotsummary
# SKIPPING
# -------------------- Scraping movie url 292/490 --------------------
# https://www.imdb.com/title/tt11285280/plotsummary
# SKIPPING
# -------------------- Scraping movie url 293/490 --------------------
# https://www.imdb.com/title/tt11285908/plotsummary
# SKIPPING
# -------------------- Scraping movie url 294/490 --------------------
# https://www.imdb.com/title/tt11307814/plotsummary
# SKIPPING
# -------------------- Scraping movie url 295/490 --------------------
# https://www.imdb.com/title/tt11310004/plotsummary
# SKIPPING
# -------------------- Scraping movie url 296/490 --------------------
# https://www.imdb.com/title/tt11311958/plotsummary
# SKIPPING
# -------------------- Scraping movie url 297/490 --------------------
# https://www.imdb.com/title/tt11314148/plotsummary
# SKIPPING
# -------------------- Scraping movie url 298/490 --------------------
# https://www.imdb.com/title/tt11316854/plotsummary
# SKIPPING
# -------------------- Scraping movie url 299/490 --------------------
# https://www.imdb.com/title/tt11317142/plotsummary
# -------------------- Scraping movie url 300/490 --------------------
# https://www.imdb.com/title/tt11322920/plotsummary
# SKIPPING
# -------------------- Scraping movie url 301/490 --------------------
# https://www.imdb.com/title/tt11323316/plotsummary
# SKIPPING
# -------------------- Scraping movie url 302/490 --------------------
# https://www.imdb.com/title/tt11327514/plotsummary
# -------------------- Scraping movie url 303/490 --------------------
# https://www.imdb.com/title/tt11343416/plotsummary
# SKIPPING
# -------------------- Scraping movie url 304/490 --------------------
# https://www.imdb.com/title/tt11350284/plotsummary
# SKIPPING
# -------------------- Scraping movie url 305/490 --------------------
# https://www.imdb.com/title/tt11358398/plotsummary
# SKIPPING
# -------------------- Scraping movie url 306/490 --------------------
# https://www.imdb.com/title/tt11374902/plotsummary
# SKIPPING
# -------------------- Scraping movie url 307/490 --------------------
# https://www.imdb.com/title/tt11384004/plotsummary
# SKIPPING
# -------------------- Scraping movie url 308/490 --------------------
# https://www.imdb.com/title/tt11385078/plotsummary
# SKIPPING
# -------------------- Scraping movie url 309/490 --------------------
# https://www.imdb.com/title/tt11385128/plotsummary
# SKIPPING
# -------------------- Scraping movie url 310/490 --------------------
# https://www.imdb.com/title/tt11388278/plotsummary
# SKIPPING
# -------------------- Scraping movie url 311/490 --------------------
# https://www.imdb.com/title/tt11388406/plotsummary
# SKIPPING
# -------------------- Scraping movie url 312/490 --------------------
# https://www.imdb.com/title/tt11390036/plotsummary
# -------------------- Scraping movie url 313/490 --------------------
# https://www.imdb.com/title/tt11394332/plotsummary
# SKIPPING
# -------------------- Scraping movie url 314/490 --------------------
# https://www.imdb.com/title/tt11418452/plotsummary
# SKIPPING
# -------------------- Scraping movie url 315/490 --------------------
# https://www.imdb.com/title/tt11423214/plotsummary
# SKIPPING
# -------------------- Scraping movie url 316/490 --------------------
# https://www.imdb.com/title/tt11448936/plotsummary
# SKIPPING
# -------------------- Scraping movie url 317/490 --------------------
# https://www.imdb.com/title/tt11454718/plotsummary
# SKIPPING
# -------------------- Scraping movie url 318/490 --------------------
# https://www.imdb.com/title/tt11456054/plotsummary
# -------------------- Scraping movie url 319/490 --------------------
# https://www.imdb.com/title/tt11460818/plotsummary
# SKIPPING
# -------------------- Scraping movie url 320/490 --------------------
# https://www.imdb.com/title/tt11499506/plotsummary
# SKIPPING
# -------------------- Scraping movie url 321/490 --------------------
# https://www.imdb.com/title/tt11502940/plotsummary
# SKIPPING
# -------------------- Scraping movie url 322/490 --------------------
# https://www.imdb.com/title/tt11503178/plotsummary
# SKIPPING
# -------------------- Scraping movie url 323/490 --------------------
# https://www.imdb.com/title/tt11525022/plotsummary
# SKIPPING
# -------------------- Scraping movie url 324/490 --------------------
# https://www.imdb.com/title/tt11525644/plotsummary
# -------------------- Scraping movie url 325/490 --------------------
# https://www.imdb.com/title/tt11527964/plotsummary
# SKIPPING
# -------------------- Scraping movie url 326/490 --------------------
# https://www.imdb.com/title/tt11531530/plotsummary
# SKIPPING
# -------------------- Scraping movie url 327/490 --------------------
# https://www.imdb.com/title/tt11536262/plotsummary
# SKIPPING
# -------------------- Scraping movie url 328/490 --------------------
# https://www.imdb.com/title/tt11547520/plotsummary
# SKIPPING
# -------------------- Scraping movie url 329/490 --------------------
# https://www.imdb.com/title/tt11576124/plotsummary
# SKIPPING
# -------------------- Scraping movie url 330/490 --------------------
# https://www.imdb.com/title/tt11580854/plotsummary
# SKIPPING
# -------------------- Scraping movie url 331/490 --------------------
# https://www.imdb.com/title/tt11581174/plotsummary
# SKIPPING
# -------------------- Scraping movie url 332/490 --------------------
# https://www.imdb.com/title/tt11591306/plotsummary
# SKIPPING
# -------------------- Scraping movie url 333/490 --------------------
# https://www.imdb.com/title/tt11591424/plotsummary
# SKIPPING
# -------------------- Scraping movie url 334/490 --------------------
# https://www.imdb.com/title/tt11604676/plotsummary
# SKIPPING
# -------------------- Scraping movie url 335/490 --------------------
# https://www.imdb.com/title/tt11614912/plotsummary
# SKIPPING
# -------------------- Scraping movie url 336/490 --------------------
# https://www.imdb.com/title/tt11617052/plotsummary
# SKIPPING
# -------------------- Scraping movie url 337/490 --------------------
# https://www.imdb.com/title/tt11618536/plotsummary
# SKIPPING
# -------------------- Scraping movie url 338/490 --------------------
# https://www.imdb.com/title/tt11640022/plotsummary
# SKIPPING
# -------------------- Scraping movie url 339/490 --------------------
# https://www.imdb.com/title/tt11648514/plotsummary
# -------------------- Scraping movie url 340/490 --------------------
# https://www.imdb.com/title/tt11650226/plotsummary
# SKIPPING
# -------------------- Scraping movie url 341/490 --------------------
# https://www.imdb.com/title/tt11651796/plotsummary
# -------------------- Scraping movie url 342/490 --------------------
# https://www.imdb.com/title/tt11655202/plotsummary
# SKIPPING
# -------------------- Scraping movie url 343/490 --------------------
# https://www.imdb.com/title/tt11656172/plotsummary
# SKIPPING
# -------------------- Scraping movie url 344/490 --------------------
# https://www.imdb.com/title/tt11656220/plotsummary
# SKIPPING
# -------------------- Scraping movie url 345/490 --------------------
# https://www.imdb.com/title/tt11656548/plotsummary
# SKIPPING
# -------------------- Scraping movie url 346/490 --------------------
# https://www.imdb.com/title/tt11657662/plotsummary
# -------------------- Scraping movie url 347/490 --------------------
# https://www.imdb.com/title/tt11658120/plotsummary
# SKIPPING
# -------------------- Scraping movie url 348/490 --------------------
# https://www.imdb.com/title/tt11681250/plotsummary
# SKIPPING
# -------------------- Scraping movie url 349/490 --------------------
# https://www.imdb.com/title/tt11686490/plotsummary
# SKIPPING
# -------------------- Scraping movie url 350/490 --------------------
# https://www.imdb.com/title/tt11697484/plotsummary
# SKIPPING
# -------------------- Scraping movie url 351/490 --------------------
# https://www.imdb.com/title/tt11697690/plotsummary
# SKIPPING
# -------------------- Scraping movie url 352/490 --------------------
# https://www.imdb.com/title/tt11698630/plotsummary
# SKIPPING
# -------------------- Scraping movie url 353/490 --------------------
# https://www.imdb.com/title/tt11734264/plotsummary
# SKIPPING
# -------------------- Scraping movie url 354/490 --------------------
# https://www.imdb.com/title/tt11742798/plotsummary
# SKIPPING
# -------------------- Scraping movie url 355/490 --------------------
# https://www.imdb.com/title/tt11750282/plotsummary
# -------------------- Scraping movie url 356/490 --------------------
# https://www.imdb.com/title/tt11762434/plotsummary
# -------------------- Scraping movie url 357/490 --------------------
# https://www.imdb.com/title/tt11773456/plotsummary
# SKIPPING
# -------------------- Scraping movie url 358/490 --------------------
# https://www.imdb.com/title/tt11777040/plotsummary
# SKIPPING
# -------------------- Scraping movie url 359/490 --------------------
# https://www.imdb.com/title/tt11777738/plotsummary
# SKIPPING
# -------------------- Scraping movie url 360/490 --------------------
# https://www.imdb.com/title/tt11778118/plotsummary
# SKIPPING
# -------------------- Scraping movie url 361/490 --------------------
# https://www.imdb.com/title/tt11792734/plotsummary
# SKIPPING
# -------------------- Scraping movie url 362/490 --------------------
# https://www.imdb.com/title/tt11804152/plotsummary
# SKIPPING
# -------------------- Scraping movie url 363/490 --------------------
# https://www.imdb.com/title/tt11809034/plotsummary
# SKIPPING
# -------------------- Scraping movie url 364/490 --------------------
# https://www.imdb.com/title/tt11815960/plotsummary
# SKIPPING
# -------------------- Scraping movie url 365/490 --------------------
# https://www.imdb.com/title/tt11816092/plotsummary
# SKIPPING
# -------------------- Scraping movie url 366/490 --------------------
# https://www.imdb.com/title/tt11905962/plotsummary
# SKIPPING
# -------------------- Scraping movie url 367/490 --------------------
# https://www.imdb.com/title/tt11908062/plotsummary
# SKIPPING
# -------------------- Scraping movie url 368/490 --------------------
# https://www.imdb.com/title/tt11908982/plotsummary
# SKIPPING
# -------------------- Scraping movie url 369/490 --------------------
# https://www.imdb.com/title/tt11946300/plotsummary
# SKIPPING
# -------------------- Scraping movie url 370/490 --------------------
# https://www.imdb.com/title/tt11958344/plotsummary
# SKIPPING
# -------------------- Scraping movie url 371/490 --------------------
# https://www.imdb.com/title/tt11988512/plotsummary
# SKIPPING
# -------------------- Scraping movie url 372/490 --------------------
# https://www.imdb.com/title/tt11991748/plotsummary
# SKIPPING
# -------------------- Scraping movie url 373/490 --------------------
# https://www.imdb.com/title/tt12036052/plotsummary
# -------------------- Scraping movie url 374/490 --------------------
# https://www.imdb.com/title/tt12108622/plotsummary
# -------------------- Scraping movie url 375/490 --------------------
# https://www.imdb.com/title/tt12137964/plotsummary
# -------------------- Scraping movie url 376/490 --------------------
# https://www.imdb.com/title/tt12151820/plotsummary
# SKIPPING
# -------------------- Scraping movie url 377/490 --------------------
# https://www.imdb.com/title/tt12274228/plotsummary
# -------------------- Scraping movie url 378/490 --------------------
# https://www.imdb.com/title/tt12282598/plotsummary
# SKIPPING
# -------------------- Scraping movie url 379/490 --------------------
# https://www.imdb.com/title/tt12283738/plotsummary
# SKIPPING
# -------------------- Scraping movie url 380/490 --------------------
# https://www.imdb.com/title/tt12298506/plotsummary
# SKIPPING
# -------------------- Scraping movie url 381/490 --------------------
# https://www.imdb.com/title/tt12335692/plotsummary
# SKIPPING
# -------------------- Scraping movie url 382/490 --------------------
# https://www.imdb.com/title/tt12361178/plotsummary
# -------------------- Scraping movie url 383/490 --------------------
# https://www.imdb.com/title/tt12361974/plotsummary
# -------------------- Scraping movie url 384/490 --------------------
# https://www.imdb.com/title/tt12383460/plotsummary
# SKIPPING
# -------------------- Scraping movie url 385/490 --------------------
# https://www.imdb.com/title/tt12393526/plotsummary
# SKIPPING
# -------------------- Scraping movie url 386/490 --------------------
# https://www.imdb.com/title/tt12415546/plotsummary
# SKIPPING
# -------------------- Scraping movie url 387/490 --------------------
# https://www.imdb.com/title/tt12443946/plotsummary
# SKIPPING
# -------------------- Scraping movie url 388/490 --------------------
# https://www.imdb.com/title/tt12474056/plotsummary
# SKIPPING
# -------------------- Scraping movie url 389/490 --------------------
# https://www.imdb.com/title/tt12528166/plotsummary
# SKIPPING
# -------------------- Scraping movie url 390/490 --------------------
# https://www.imdb.com/title/tt12536294/plotsummary
# SKIPPING
# -------------------- Scraping movie url 391/490 --------------------
# https://www.imdb.com/title/tt12567088/plotsummary
# SKIPPING
# -------------------- Scraping movie url 392/490 --------------------
# https://www.imdb.com/title/tt12592252/plotsummary
# SKIPPING
# -------------------- Scraping movie url 393/490 --------------------
# https://www.imdb.com/title/tt12607910/plotsummary
# SKIPPING
# -------------------- Scraping movie url 394/490 --------------------
# https://www.imdb.com/title/tt12676326/plotsummary
# -------------------- Scraping movie url 395/490 --------------------
# https://www.imdb.com/title/tt12677092/plotsummary
# -------------------- Scraping movie url 396/490 --------------------
# https://www.imdb.com/title/tt12680508/plotsummary
# SKIPPING
# -------------------- Scraping movie url 397/490 --------------------
# https://www.imdb.com/title/tt12687276/plotsummary
# SKIPPING
# -------------------- Scraping movie url 398/490 --------------------
# https://www.imdb.com/title/tt12731980/plotsummary
# -------------------- Scraping movie url 399/490 --------------------
# https://www.imdb.com/title/tt12735338/plotsummary
# SKIPPING
# -------------------- Scraping movie url 400/490 --------------------
# https://www.imdb.com/title/tt12758600/plotsummary
# SKIPPING
# -------------------- Scraping movie url 401/490 --------------------
# https://www.imdb.com/title/tt12763920/plotsummary
# -------------------- Scraping movie url 402/490 --------------------
# https://www.imdb.com/title/tt12783454/plotsummary
# SKIPPING
# -------------------- Scraping movie url 403/490 --------------------
# https://www.imdb.com/title/tt12792418/plotsummary
# SKIPPING
# -------------------- Scraping movie url 404/490 --------------------
# https://www.imdb.com/title/tt12801262/plotsummary
# -------------------- Scraping movie url 405/490 --------------------
# https://www.imdb.com/title/tt12808182/plotsummary
# SKIPPING
# -------------------- Scraping movie url 406/490 --------------------
# https://www.imdb.com/title/tt12829958/plotsummary
# SKIPPING
# -------------------- Scraping movie url 407/490 --------------------
# https://www.imdb.com/title/tt12838766/plotsummary
# -------------------- Scraping movie url 408/490 --------------------
# https://www.imdb.com/title/tt12839816/plotsummary
# SKIPPING
# -------------------- Scraping movie url 409/490 --------------------
# https://www.imdb.com/title/tt12851396/plotsummary
# SKIPPING
# -------------------- Scraping movie url 410/490 --------------------
# https://www.imdb.com/title/tt12861508/plotsummary
# SKIPPING
# -------------------- Scraping movie url 411/490 --------------------
# https://www.imdb.com/title/tt12875782/plotsummary
# SKIPPING
# -------------------- Scraping movie url 412/490 --------------------
# https://www.imdb.com/title/tt12876132/plotsummary
# SKIPPING
# -------------------- Scraping movie url 413/490 --------------------
# https://www.imdb.com/title/tt12877640/plotsummary
# SKIPPING
# -------------------- Scraping movie url 414/490 --------------------
# https://www.imdb.com/title/tt12879624/plotsummary
# SKIPPING
# -------------------- Scraping movie url 415/490 --------------------
# https://www.imdb.com/title/tt12882620/plotsummary
# SKIPPING
# -------------------- Scraping movie url 416/490 --------------------
# https://www.imdb.com/title/tt12885852/plotsummary
# SKIPPING
# -------------------- Scraping movie url 417/490 --------------------
# https://www.imdb.com/title/tt12887178/plotsummary
# SKIPPING
# -------------------- Scraping movie url 418/490 --------------------
# https://www.imdb.com/title/tt12929738/plotsummary
# SKIPPING
# -------------------- Scraping movie url 419/490 --------------------
# https://www.imdb.com/title/tt12929990/plotsummary
# SKIPPING
# -------------------- Scraping movie url 420/490 --------------------
# https://www.imdb.com/title/tt12971924/plotsummary
# SKIPPING
# -------------------- Scraping movie url 421/490 --------------------
# https://www.imdb.com/title/tt12982370/plotsummary
# SKIPPING
# -------------------- Scraping movie url 422/490 --------------------
# https://www.imdb.com/title/tt12986942/plotsummary
# -------------------- Scraping movie url 423/490 --------------------
# https://www.imdb.com/title/tt13024674/plotsummary
# SKIPPING
# -------------------- Scraping movie url 424/490 --------------------
# https://www.imdb.com/title/tt13045890/plotsummary
# SKIPPING
# -------------------- Scraping movie url 425/490 --------------------
# https://www.imdb.com/title/tt13055780/plotsummary
# SKIPPING
# -------------------- Scraping movie url 426/490 --------------------
# https://www.imdb.com/title/tt13056008/plotsummary
# SKIPPING
# -------------------- Scraping movie url 427/490 --------------------
# https://www.imdb.com/title/tt13061914/plotsummary
# -------------------- Scraping movie url 428/490 --------------------
# https://www.imdb.com/title/tt13067004/plotsummary
# SKIPPING
# -------------------- Scraping movie url 429/490 --------------------
# https://www.imdb.com/title/tt13069986/plotsummary
# SKIPPING
# -------------------- Scraping movie url 430/490 --------------------
# https://www.imdb.com/title/tt13087796/plotsummary
# SKIPPING
# -------------------- Scraping movie url 431/490 --------------------
# https://www.imdb.com/title/tt13095604/plotsummary
# -------------------- Scraping movie url 432/490 --------------------
# https://www.imdb.com/title/tt13097434/plotsummary
# SKIPPING
# -------------------- Scraping movie url 433/490 --------------------
# https://www.imdb.com/title/tt13103212/plotsummary
# SKIPPING
# -------------------- Scraping movie url 434/490 --------------------
# https://www.imdb.com/title/tt13109952/plotsummary
# SKIPPING
# -------------------- Scraping movie url 435/490 --------------------
# https://www.imdb.com/title/tt13143964/plotsummary
# SKIPPING
# -------------------- Scraping movie url 436/490 --------------------
# https://www.imdb.com/title/tt13143988/plotsummary
# SKIPPING
# -------------------- Scraping movie url 437/490 --------------------
# https://www.imdb.com/title/tt13162144/plotsummary
# SKIPPING
# -------------------- Scraping movie url 438/490 --------------------
# https://www.imdb.com/title/tt13172796/plotsummary
# SKIPPING
# -------------------- Scraping movie url 439/490 --------------------
# https://www.imdb.com/title/tt13206926/plotsummary
# SKIPPING
# -------------------- Scraping movie url 440/490 --------------------
# https://www.imdb.com/title/tt13234058/plotsummary
# SKIPPING
# -------------------- Scraping movie url 441/490 --------------------
# https://www.imdb.com/title/tt13236566/plotsummary
# SKIPPING
# -------------------- Scraping movie url 442/490 --------------------
# https://www.imdb.com/title/tt13269536/plotsummary
# SKIPPING
# -------------------- Scraping movie url 443/490 --------------------
# https://www.imdb.com/title/tt13298992/plotsummary
# SKIPPING
# -------------------- Scraping movie url 444/490 --------------------
# https://www.imdb.com/title/tt13316722/plotsummary
# SKIPPING
# -------------------- Scraping movie url 445/490 --------------------
# https://www.imdb.com/title/tt13317694/plotsummary
# SKIPPING
# -------------------- Scraping movie url 446/490 --------------------
# https://www.imdb.com/title/tt13350412/plotsummary
# SKIPPING
# -------------------- Scraping movie url 447/490 --------------------
# https://www.imdb.com/title/tt13354204/plotsummary
# -------------------- Scraping movie url 448/490 --------------------
# https://www.imdb.com/title/tt13372794/plotsummary
# SKIPPING
# -------------------- Scraping movie url 449/490 --------------------
# https://www.imdb.com/title/tt13391696/plotsummary
# SKIPPING
# -------------------- Scraping movie url 450/490 --------------------
# https://www.imdb.com/title/tt13392012/plotsummary
# SKIPPING
# -------------------- Scraping movie url 451/490 --------------------
# https://www.imdb.com/title/tt13421132/plotsummary
# SKIPPING
# -------------------- Scraping movie url 452/490 --------------------
# https://www.imdb.com/title/tt13428402/plotsummary
# SKIPPING
# -------------------- Scraping movie url 453/490 --------------------
# https://www.imdb.com/title/tt13429362/plotsummary
# SKIPPING
# -------------------- Scraping movie url 454/490 --------------------
# https://www.imdb.com/title/tt13485172/plotsummary
# SKIPPING
# -------------------- Scraping movie url 455/490 --------------------
# https://www.imdb.com/title/tt13491620/plotsummary
# -------------------- Scraping movie url 456/490 --------------------
# https://www.imdb.com/title/tt13507778/plotsummary
# SKIPPING
# -------------------- Scraping movie url 457/490 --------------------
# https://www.imdb.com/title/tt13551614/plotsummary
# SKIPPING
# -------------------- Scraping movie url 458/490 --------------------
# https://www.imdb.com/title/tt13562940/plotsummary
# SKIPPING
# -------------------- Scraping movie url 459/490 --------------------
# https://www.imdb.com/title/tt13598976/plotsummary
# SKIPPING
# -------------------- Scraping movie url 460/490 --------------------
# https://www.imdb.com/title/tt13698928/plotsummary
# SKIPPING
# -------------------- Scraping movie url 461/490 --------------------
# https://www.imdb.com/title/tt13717980/plotsummary
# SKIPPING
# -------------------- Scraping movie url 462/490 --------------------
# https://www.imdb.com/title/tt13723064/plotsummary
# SKIPPING
# -------------------- Scraping movie url 463/490 --------------------
# https://www.imdb.com/title/tt13804084/plotsummary
# SKIPPING
# -------------------- Scraping movie url 464/490 --------------------
# https://www.imdb.com/title/tt13834006/plotsummary
# SKIPPING
# -------------------- Scraping movie url 465/490 --------------------
# https://www.imdb.com/title/tt13846542/plotsummary
# SKIPPING
# -------------------- Scraping movie url 466/490 --------------------
# https://www.imdb.com/title/tt13912632/plotsummary
# SKIPPING
# -------------------- Scraping movie url 467/490 --------------------
# https://www.imdb.com/title/tt13932162/plotsummary
# SKIPPING
# -------------------- Scraping movie url 468/490 --------------------
# https://www.imdb.com/title/tt14025788/plotsummary
# SKIPPING
# -------------------- Scraping movie url 469/490 --------------------
# https://www.imdb.com/title/tt14091818/plotsummary
# SKIPPING
# -------------------- Scraping movie url 470/490 --------------------
# https://www.imdb.com/title/tt14111734/plotsummary
# SKIPPING
# -------------------- Scraping movie url 471/490 --------------------
# https://www.imdb.com/title/tt14217100/plotsummary
# SKIPPING
# -------------------- Scraping movie url 472/490 --------------------
# https://www.imdb.com/title/tt14252742/plotsummary
# SKIPPING
# -------------------- Scraping movie url 473/490 --------------------
# https://www.imdb.com/title/tt14260080/plotsummary
# SKIPPING
# -------------------- Scraping movie url 474/490 --------------------
# https://www.imdb.com/title/tt14280066/plotsummary
# SKIPPING
# -------------------- Scraping movie url 475/490 --------------------
# https://www.imdb.com/title/tt14315500/plotsummary
# SKIPPING
# -------------------- Scraping movie url 476/490 --------------------
# https://www.imdb.com/title/tt14403632/plotsummary
# SKIPPING
# -------------------- Scraping movie url 477/490 --------------------
# https://www.imdb.com/title/tt14404280/plotsummary
# SKIPPING
# -------------------- Scraping movie url 478/490 --------------------
# https://www.imdb.com/title/tt14418234/plotsummary
# SKIPPING
# -------------------- Scraping movie url 479/490 --------------------
# https://www.imdb.com/title/tt14527836/plotsummary
# SKIPPING
# -------------------- Scraping movie url 480/490 --------------------
# https://www.imdb.com/title/tt14565414/plotsummary
# SKIPPING
# -------------------- Scraping movie url 481/490 --------------------
# https://www.imdb.com/title/tt14640242/plotsummary
# SKIPPING
# -------------------- Scraping movie url 482/490 --------------------
# https://www.imdb.com/title/tt14723224/plotsummary
# SKIPPING
# -------------------- Scraping movie url 483/490 --------------------
# https://www.imdb.com/title/tt14781176/plotsummary
# SKIPPING
# -------------------- Scraping movie url 484/490 --------------------
# https://www.imdb.com/title/tt14867006/plotsummary
# SKIPPING
# -------------------- Scraping movie url 485/490 --------------------
# https://www.imdb.com/title/tt14878948/plotsummary
# SKIPPING
# -------------------- Scraping movie url 486/490 --------------------
# https://www.imdb.com/title/tt14901058/plotsummary
# SKIPPING
# -------------------- Scraping movie url 487/490 --------------------
# https://www.imdb.com/title/tt15010478/plotsummary
# SKIPPING
# -------------------- Scraping movie url 488/490 --------------------
# https://www.imdb.com/title/tt15097216/plotsummary
# SKIPPING
# -------------------- Scraping movie url 489/490 --------------------
# https://www.imdb.com/title/tt15198608/plotsummary
# SKIPPING
# -------------------- Scraping movie url 490/490 --------------------
# https://www.imdb.com/title/tt15264532/plotsummary
# SKIPPING

# %%
fileList = glob.glob("../movieFile/*.txt")
activeMovs = []
for i in fileList:
    activeMovs.append(i.replace('../movieFile/','').replace('.txt',''))
    
df_act_movs = pd.DataFrame(activeMovs)
df_act_movs.columns = ['tconst']
df_act_movs.head()
# Out:
#       tconst
# 0  tt0250687
# 1  tt0405393
# 2  tt2318092
# 3  tt0118647
# 4  tt0101316

# %%
print(len(actors))
actors = actors.merge(df_act_movs,how='inner')
print(len(actors))
# Out:
# 57041
# 28176

# %% [markdown]
# # Store actors list with the scraped movies

# %%
print(len(actors))
actors.to_csv('../files/actors.csv',header=True,index=False)
actors.head()
# Out:
# 28176
#       nconst    primaryName     tconst
# 0  nm0000004   John Belushi  tt0077975
# 1  nm0000261    Karen Allen  tt0077975
# 2  nm0001371      Tom Hulce  tt0077975
# 3  nm0299122  Stephen Furst  tt0077975
# 4  nm0000004   John Belushi  tt0078723

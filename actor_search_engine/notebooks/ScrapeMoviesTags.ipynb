# %% [markdown]
# # Read actors File

# %%
import pandas as pd
from os.path import exists
import glob
actors = pd.read_csv('../files/actors.csv', header=0)

# %% [markdown]
# # Apply Filters

# %%
print("Actor Count before Filter:",len(actors))
#actors = actors[0:1000]
actors = actors.reset_index(drop=True)
print(len(actors))
actors.head()
# Out:
# Actor Count before Filter: 28176
# 28176
#       nconst    primaryName     tconst
# 0  nm0000004   John Belushi  tt0077975
# 1  nm0000261    Karen Allen  tt0077975
# 2  nm0001371      Tom Hulce  tt0077975
# 3  nm0299122  Stephen Furst  tt0077975
# 4  nm0000004   John Belushi  tt0078723

# %% [markdown]
# # Check Samples

# %% [markdown]
# # Get Unique Titles for Actors

# %%
uniqTitlesList = list(set(actors['tconst']))
uniqTitlesList.sort()
print(len(uniqTitlesList))
# Out:
# 8905

# %% [markdown]
# # Scrape Related Fuctions

# %%
from bs4 import BeautifulSoup
from selenium import webdriver 
from selenium.webdriver.chrome.options import Options
import re 
import urllib
import time

# %%
#create a webdriver object and set options for headless browsing
options = Options()
options.headless = True
driver = webdriver.Chrome('../chromedriver',options=options)

# %%
#uses webdriver object to execute javascript code and get dynamically loaded webcontent
def get_js_soup(url,driver):
    driver.get(url)
    res_html = driver.execute_script('return document.body.innerHTML')
    soup = BeautifulSoup(res_html,'html.parser') #beautiful soup object to be used for parsing html content
    return soup

#tidies extracted text 
def process_mov(mov):
    mov = mov.encode('ascii',errors='ignore').decode('utf-8')       #removes non-ascii characters
    mov = re.sub('\s+',' ',mov)       #repalces repeated whitespace characters with single space
    return mov

''' More tidying
Sometimes the text extracted HTML webpage may contain javascript code and some style elements. 
This function removes script and style tags from HTML so that extracted text does not contain them.
'''
def remove_script(soup):
    for script in soup(["script", "style"]):
        script.decompose()
    return soup


#Checks if bio_url is a valid faculty homepage
def is_valid_homepage(mov_url,dir_url):
    if mov_url.endswith('.pdf'): #we're not parsing pdfs
        return False
    try:
        #sometimes the homepage url points to the same page as the faculty profile page
        #which should be treated differently from an actual homepage
        ret_url = urllib.request.urlopen(mov_url).geturl() 
    except:
        return False       #unable to access bio_url
    urls = [re.sub('((https?://)|(www.))','',url) for url in [ret_url,dir_url]] #removes url scheme (https,http or www) 
    return not(urls[0]== urls[1])

def scrape_movie_page(mov_url,driver):
    soup = get_js_soup(mov_url,driver)
    homepage_found = False
    #profile_sec = soup.find('section',class_='main-content')
    profile_sec = soup.find('div',class_='article listo')
    if profile_sec == None:
        mov = ''
        print("Skipping mov : ",mov_url)
    else:
        mov = process_mov(profile_sec.get_text(separator=' '))
    return mov_url,mov

# %%
def write_lst(lst,file_):
    lst = lst.replace(' Plot Keywords Sort By: Relevance Alphabetical Showing all ',' ')
    lst = lst.replace(' found this relevant Relevant? Yes No ',' ')
    lst = lst.replace(' Is this relevant? Relevant? Yes No ',' ')
    lst = lst.replace(' 1 of 1 ',' ').replace(' 0 of 1 ',' ')
    lst = lst.replace(' 2 of 2 ',' ').replace(' 0 of 2 ',' ').replace(' 1 of 2 ',' ')
    lst = lst.replace(' 3 of 3 ',' ').replace(' 0 of 3 ',' ').replace(' 1 of 3 ',' ').replace(' 2 of 3 ',' ')
    lst = lst.replace(' Plot Showing all ','').replace(' items Jump to: Summaries (','')
    lst = lst.replace('  ',' ').replace('   ',' ')

    lst = lst.replace('Edit ','')


    with open(file_,'w') as f:
        f.write(lst)

# %% [markdown]
# # Scrape Movie Tags and store in "movieFileTags" dir

# %%
fileList = glob.glob("../movieFileTags/*.txt")

fileListVals = []
for i in fileList:
    fileListVals.append(int(i.replace('../movieFileTags/','').replace('.txt','').replace('tt','')))
    
print(len(fileListVals),max(fileListVals))
    

if len(fileList) <= 0:
    last_scraped = 0
else:
    last_scraped = (max(fileListVals))


uniqTitlesInt = sorted(int(i.replace('tt','')) for i in uniqTitlesList if int(i.replace('tt','')) > last_scraped)

uniqTitles = []
for i in uniqTitlesInt:
    uniqTitles.append('tt'+str(i))
    
print('tt' + str(last_scraped))
print(len(uniqTitles))
# Out:
# 7618 4591310
# tt4591310
# 853

# %%
#Scrape homepages of all urls
tot_urls = len(uniqTitles)
for i,l in enumerate(uniqTitles):
    link="https://www.imdb.com/title/"+l+"/keywords"
    print ('-'*20,'Scraping movie url {}/{}'.format(i+1,tot_urls),'-'*20)
    print(link)
    mov_urls, movs = [],[]
    mov_url,mov = scrape_movie_page(link,driver)
    if len(mov) < 10:
        print("SKIPPING")
    else:
        if mov.strip()!= '' and mov_url.strip()!='':
            mov_file = '../movieFileTags/'+l+'.txt'
            write_lst(mov,mov_file)
driver.close()
# Out:
# -------------------- Scraping movie url 1/853 --------------------
# https://www.imdb.com/title/tt4595882/keywords
# -------------------- Scraping movie url 2/853 --------------------
# https://www.imdb.com/title/tt4600952/keywords
# -------------------- Scraping movie url 3/853 --------------------
# https://www.imdb.com/title/tt4621630/keywords
# -------------------- Scraping movie url 4/853 --------------------
# https://www.imdb.com/title/tt4622512/keywords
# -------------------- Scraping movie url 5/853 --------------------
# https://www.imdb.com/title/tt4624424/keywords
# -------------------- Scraping movie url 6/853 --------------------
# https://www.imdb.com/title/tt4629266/keywords
# -------------------- Scraping movie url 7/853 --------------------
# https://www.imdb.com/title/tt4630562/keywords
# -------------------- Scraping movie url 8/853 --------------------
# https://www.imdb.com/title/tt4633690/keywords
# -------------------- Scraping movie url 9/853 --------------------
# https://www.imdb.com/title/tt4633694/keywords
# -------------------- Scraping movie url 10/853 --------------------
# https://www.imdb.com/title/tt4638148/keywords
# -------------------- Scraping movie url 11/853 --------------------
# https://www.imdb.com/title/tt4642192/keywords
# -------------------- Scraping movie url 12/853 --------------------
# https://www.imdb.com/title/tt4645368/keywords
# -------------------- Scraping movie url 13/853 --------------------
# https://www.imdb.com/title/tt4648786/keywords
# -------------------- Scraping movie url 14/853 --------------------
# https://www.imdb.com/title/tt4649416/keywords
# -------------------- Scraping movie url 15/853 --------------------
# https://www.imdb.com/title/tt4649466/keywords
# -------------------- Scraping movie url 16/853 --------------------
# https://www.imdb.com/title/tt4651520/keywords
# -------------------- Scraping movie url 17/853 --------------------
# https://www.imdb.com/title/tt4652650/keywords
# -------------------- Scraping movie url 18/853 --------------------
# https://www.imdb.com/title/tt4659056/keywords
# -------------------- Scraping movie url 19/853 --------------------
# https://www.imdb.com/title/tt4667094/keywords
# -------------------- Scraping movie url 20/853 --------------------
# https://www.imdb.com/title/tt4669788/keywords
# -------------------- Scraping movie url 21/853 --------------------
# https://www.imdb.com/title/tt4669986/keywords
# -------------------- Scraping movie url 22/853 --------------------
# https://www.imdb.com/title/tt4670016/keywords
# -------------------- Scraping movie url 23/853 --------------------
# https://www.imdb.com/title/tt4679210/keywords
# -------------------- Scraping movie url 24/853 --------------------
# https://www.imdb.com/title/tt4680182/keywords
# -------------------- Scraping movie url 25/853 --------------------
# https://www.imdb.com/title/tt4682266/keywords
# -------------------- Scraping movie url 26/853 --------------------
# https://www.imdb.com/title/tt4682780/keywords
# -------------------- Scraping movie url 27/853 --------------------
# https://www.imdb.com/title/tt4682786/keywords
# -------------------- Scraping movie url 28/853 --------------------
# https://www.imdb.com/title/tt4683366/keywords
# -------------------- Scraping movie url 29/853 --------------------
# https://www.imdb.com/title/tt4685762/keywords
# -------------------- Scraping movie url 30/853 --------------------
# https://www.imdb.com/title/tt4686844/keywords
# -------------------- Scraping movie url 31/853 --------------------
# https://www.imdb.com/title/tt4687108/keywords
# -------------------- Scraping movie url 32/853 --------------------
# https://www.imdb.com/title/tt4687358/keywords
# -------------------- Scraping movie url 33/853 --------------------
# https://www.imdb.com/title/tt4695012/keywords
# -------------------- Scraping movie url 34/853 --------------------
# https://www.imdb.com/title/tt4695098/keywords
# -------------------- Scraping movie url 35/853 --------------------
# https://www.imdb.com/title/tt4695548/keywords
# -------------------- Scraping movie url 36/853 --------------------
# https://www.imdb.com/title/tt4698684/keywords
# -------------------- Scraping movie url 37/853 --------------------
# https://www.imdb.com/title/tt4701182/keywords
# -------------------- Scraping movie url 38/853 --------------------
# https://www.imdb.com/title/tt4701724/keywords
# -------------------- Scraping movie url 39/853 --------------------
# https://www.imdb.com/title/tt4703048/keywords
# -------------------- Scraping movie url 40/853 --------------------
# https://www.imdb.com/title/tt4714782/keywords
# -------------------- Scraping movie url 41/853 --------------------
# https://www.imdb.com/title/tt4720596/keywords
# -------------------- Scraping movie url 42/853 --------------------
# https://www.imdb.com/title/tt4721124/keywords
# -------------------- Scraping movie url 43/853 --------------------
# https://www.imdb.com/title/tt4727512/keywords
# -------------------- Scraping movie url 44/853 --------------------
# https://www.imdb.com/title/tt4728386/keywords
# -------------------- Scraping movie url 45/853 --------------------
# https://www.imdb.com/title/tt4729430/keywords
# -------------------- Scraping movie url 46/853 --------------------
# https://www.imdb.com/title/tt4730986/keywords
# -------------------- Scraping movie url 47/853 --------------------
# https://www.imdb.com/title/tt4731008/keywords
# -------------------- Scraping movie url 48/853 --------------------
# https://www.imdb.com/title/tt4731136/keywords
# -------------------- Scraping movie url 49/853 --------------------
# https://www.imdb.com/title/tt4733624/keywords
# -------------------- Scraping movie url 50/853 --------------------
# https://www.imdb.com/title/tt4738174/keywords
# -------------------- Scraping movie url 51/853 --------------------
# https://www.imdb.com/title/tt4746484/keywords
# -------------------- Scraping movie url 52/853 --------------------
# https://www.imdb.com/title/tt4761916/keywords
# -------------------- Scraping movie url 53/853 --------------------
# https://www.imdb.com/title/tt4765284/keywords
# -------------------- Scraping movie url 54/853 --------------------
# https://www.imdb.com/title/tt4776998/keywords
# -------------------- Scraping movie url 55/853 --------------------
# https://www.imdb.com/title/tt4777008/keywords
# -------------------- Scraping movie url 56/853 --------------------
# https://www.imdb.com/title/tt4779682/keywords
# -------------------- Scraping movie url 57/853 --------------------
# https://www.imdb.com/title/tt4781612/keywords
# -------------------- Scraping movie url 58/853 --------------------
# https://www.imdb.com/title/tt4786282/keywords
# -------------------- Scraping movie url 59/853 --------------------
# https://www.imdb.com/title/tt4795124/keywords
# -------------------- Scraping movie url 60/853 --------------------
# https://www.imdb.com/title/tt4796122/keywords
# -------------------- Scraping movie url 61/853 --------------------
# https://www.imdb.com/title/tt4799050/keywords
# -------------------- Scraping movie url 62/853 --------------------
# https://www.imdb.com/title/tt4799064/keywords
# -------------------- Scraping movie url 63/853 --------------------
# https://www.imdb.com/title/tt4799066/keywords
# -------------------- Scraping movie url 64/853 --------------------
# https://www.imdb.com/title/tt4814290/keywords
# -------------------- Scraping movie url 65/853 --------------------
# https://www.imdb.com/title/tt4815122/keywords
# -------------------- Scraping movie url 66/853 --------------------
# https://www.imdb.com/title/tt4824308/keywords
# -------------------- Scraping movie url 67/853 --------------------
# https://www.imdb.com/title/tt4827558/keywords
# -------------------- Scraping movie url 68/853 --------------------
# https://www.imdb.com/title/tt4827986/keywords
# -------------------- Scraping movie url 69/853 --------------------
# https://www.imdb.com/title/tt4832640/keywords
# -------------------- Scraping movie url 70/853 --------------------
# https://www.imdb.com/title/tt4842646/keywords
# -------------------- Scraping movie url 71/853 --------------------
# https://www.imdb.com/title/tt4844148/keywords
# -------------------- Scraping movie url 72/853 --------------------
# https://www.imdb.com/title/tt4846232/keywords
# -------------------- Scraping movie url 73/853 --------------------
# https://www.imdb.com/title/tt4846340/keywords
# -------------------- Scraping movie url 74/853 --------------------
# https://www.imdb.com/title/tt4849438/keywords
# -------------------- Scraping movie url 75/853 --------------------
# https://www.imdb.com/title/tt4853102/keywords
# -------------------- Scraping movie url 76/853 --------------------
# https://www.imdb.com/title/tt4857264/keywords
# -------------------- Scraping movie url 77/853 --------------------
# https://www.imdb.com/title/tt4858674/keywords
# -------------------- Scraping movie url 78/853 --------------------
# https://www.imdb.com/title/tt4865436/keywords
# -------------------- Scraping movie url 79/853 --------------------
# https://www.imdb.com/title/tt4866448/keywords
# -------------------- Scraping movie url 80/853 --------------------
# https://www.imdb.com/title/tt4876134/keywords
# -------------------- Scraping movie url 81/853 --------------------
# https://www.imdb.com/title/tt4877122/keywords
# -------------------- Scraping movie url 82/853 --------------------
# https://www.imdb.com/title/tt4881806/keywords
# -------------------- Scraping movie url 83/853 --------------------
# https://www.imdb.com/title/tt4900716/keywords
# -------------------- Scraping movie url 84/853 --------------------
# https://www.imdb.com/title/tt4906960/keywords
# -------------------- Scraping movie url 85/853 --------------------
# https://www.imdb.com/title/tt4907206/keywords
# -------------------- Scraping movie url 86/853 --------------------
# https://www.imdb.com/title/tt4912910/keywords
# -------------------- Scraping movie url 87/853 --------------------
# https://www.imdb.com/title/tt4913966/keywords
# -------------------- Scraping movie url 88/853 --------------------
# https://www.imdb.com/title/tt4916630/keywords
# -------------------- Scraping movie url 89/853 --------------------
# https://www.imdb.com/title/tt4922674/keywords
# -------------------- Scraping movie url 90/853 --------------------
# https://www.imdb.com/title/tt4922692/keywords
# -------------------- Scraping movie url 91/853 --------------------
# https://www.imdb.com/title/tt4924942/keywords
# -------------------- Scraping movie url 92/853 --------------------
# https://www.imdb.com/title/tt4925292/keywords
# -------------------- Scraping movie url 93/853 --------------------
# https://www.imdb.com/title/tt4934950/keywords
# -------------------- Scraping movie url 94/853 --------------------
# https://www.imdb.com/title/tt4936450/keywords
# -------------------- Scraping movie url 95/853 --------------------
# https://www.imdb.com/title/tt4939066/keywords
# -------------------- Scraping movie url 96/853 --------------------
# https://www.imdb.com/title/tt4940416/keywords
# -------------------- Scraping movie url 97/853 --------------------
# https://www.imdb.com/title/tt4961380/keywords
# -------------------- Scraping movie url 98/853 --------------------
# https://www.imdb.com/title/tt4966532/keywords
# -------------------- Scraping movie url 99/853 --------------------
# https://www.imdb.com/title/tt4971344/keywords
# -------------------- Scraping movie url 100/853 --------------------
# https://www.imdb.com/title/tt4972062/keywords
# -------------------- Scraping movie url 101/853 --------------------
# https://www.imdb.com/title/tt4972582/keywords
# -------------------- Scraping movie url 102/853 --------------------
# https://www.imdb.com/title/tt4975722/keywords
# -------------------- Scraping movie url 103/853 --------------------
# https://www.imdb.com/title/tt4978274/keywords
# -------------------- Scraping movie url 104/853 --------------------
# https://www.imdb.com/title/tt4981636/keywords
# -------------------- Scraping movie url 105/853 --------------------
# https://www.imdb.com/title/tt4981966/keywords
# -------------------- Scraping movie url 106/853 --------------------
# https://www.imdb.com/title/tt4995776/keywords
# -------------------- Scraping movie url 107/853 --------------------
# https://www.imdb.com/title/tt4995790/keywords
# -------------------- Scraping movie url 108/853 --------------------
# https://www.imdb.com/title/tt4998772/keywords
# -------------------- Scraping movie url 109/853 --------------------
# https://www.imdb.com/title/tt5001718/keywords
# -------------------- Scraping movie url 110/853 --------------------
# https://www.imdb.com/title/tt5013056/keywords
# -------------------- Scraping movie url 111/853 --------------------
# https://www.imdb.com/title/tt5023260/keywords
# -------------------- Scraping movie url 112/853 --------------------
# https://www.imdb.com/title/tt5027774/keywords
# -------------------- Scraping movie url 113/853 --------------------
# https://www.imdb.com/title/tt5028340/keywords
# -------------------- Scraping movie url 114/853 --------------------
# https://www.imdb.com/title/tt5029608/keywords
# -------------------- Scraping movie url 115/853 --------------------
# https://www.imdb.com/title/tt5033290/keywords
# -------------------- Scraping movie url 116/853 --------------------
# https://www.imdb.com/title/tt5033998/keywords
# -------------------- Scraping movie url 117/853 --------------------
# https://www.imdb.com/title/tt5034838/keywords
# -------------------- Scraping movie url 118/853 --------------------
# https://www.imdb.com/title/tt5039994/keywords
# -------------------- Scraping movie url 119/853 --------------------
# https://www.imdb.com/title/tt5052448/keywords
# -------------------- Scraping movie url 120/853 --------------------
# https://www.imdb.com/title/tt5052474/keywords
# -------------------- Scraping movie url 121/853 --------------------
# https://www.imdb.com/title/tt5057140/keywords
# -------------------- Scraping movie url 122/853 --------------------
# https://www.imdb.com/title/tt5073642/keywords
# -------------------- Scraping movie url 123/853 --------------------
# https://www.imdb.com/title/tt5074352/keywords
# -------------------- Scraping movie url 124/853 --------------------
# https://www.imdb.com/title/tt5080556/keywords
# -------------------- Scraping movie url 125/853 --------------------
# https://www.imdb.com/title/tt5083738/keywords
# -------------------- Scraping movie url 126/853 --------------------
# https://www.imdb.com/title/tt5085924/keywords
# -------------------- Scraping movie url 127/853 --------------------
# https://www.imdb.com/title/tt5089786/keywords
# -------------------- Scraping movie url 128/853 --------------------
# https://www.imdb.com/title/tt5091014/keywords
# -------------------- Scraping movie url 129/853 --------------------
# https://www.imdb.com/title/tt5091530/keywords
# -------------------- Scraping movie url 130/853 --------------------
# https://www.imdb.com/title/tt5095030/keywords
# -------------------- Scraping movie url 131/853 --------------------
# https://www.imdb.com/title/tt5097410/keywords
# -------------------- Scraping movie url 132/853 --------------------
# https://www.imdb.com/title/tt5098128/keywords
# -------------------- Scraping movie url 133/853 --------------------
# https://www.imdb.com/title/tt5104080/keywords
# -------------------- Scraping movie url 134/853 --------------------
# https://www.imdb.com/title/tt5104604/keywords
# -------------------- Scraping movie url 135/853 --------------------
# https://www.imdb.com/title/tt5109280/keywords
# -------------------- Scraping movie url 136/853 --------------------
# https://www.imdb.com/title/tt5109784/keywords
# -------------------- Scraping movie url 137/853 --------------------
# https://www.imdb.com/title/tt5113040/keywords
# -------------------- Scraping movie url 138/853 --------------------
# https://www.imdb.com/title/tt5114154/keywords
# -------------------- Scraping movie url 139/853 --------------------
# https://www.imdb.com/title/tt5117428/keywords
# -------------------- Scraping movie url 140/853 --------------------
# https://www.imdb.com/title/tt5117670/keywords
# -------------------- Scraping movie url 141/853 --------------------
# https://www.imdb.com/title/tt5119116/keywords
# -------------------- Scraping movie url 142/853 --------------------
# https://www.imdb.com/title/tt5126922/keywords
# -------------------- Scraping movie url 143/853 --------------------
# https://www.imdb.com/title/tt5133308/keywords
# -------------------- Scraping movie url 144/853 --------------------
# https://www.imdb.com/title/tt5140878/keywords
# -------------------- Scraping movie url 145/853 --------------------
# https://www.imdb.com/title/tt5143226/keywords
# -------------------- Scraping movie url 146/853 --------------------
# https://www.imdb.com/title/tt5144174/keywords
# -------------------- Scraping movie url 147/853 --------------------
# https://www.imdb.com/title/tt5153288/keywords
# -------------------- Scraping movie url 148/853 --------------------
# https://www.imdb.com/title/tt5155780/keywords
# -------------------- Scraping movie url 149/853 --------------------
# https://www.imdb.com/title/tt5157052/keywords
# -------------------- Scraping movie url 150/853 --------------------
# https://www.imdb.com/title/tt5157682/keywords
# -------------------- Scraping movie url 151/853 --------------------
# https://www.imdb.com/title/tt5158522/keywords
# -------------------- Scraping movie url 152/853 --------------------
# https://www.imdb.com/title/tt5164214/keywords
# -------------------- Scraping movie url 153/853 --------------------
# https://www.imdb.com/title/tt5164432/keywords
# -------------------- Scraping movie url 154/853 --------------------
# https://www.imdb.com/title/tt5168192/keywords
# -------------------- Scraping movie url 155/853 --------------------
# https://www.imdb.com/title/tt5175450/keywords
# -------------------- Scraping movie url 156/853 --------------------
# https://www.imdb.com/title/tt5177088/keywords
# -------------------- Scraping movie url 157/853 --------------------
# https://www.imdb.com/title/tt5178278/keywords
# -------------------- Scraping movie url 158/853 --------------------
# https://www.imdb.com/title/tt5186714/keywords
# -------------------- Scraping movie url 159/853 --------------------
# https://www.imdb.com/title/tt5198068/keywords
# -------------------- Scraping movie url 160/853 --------------------
# https://www.imdb.com/title/tt5208252/keywords
# -------------------- Scraping movie url 161/853 --------------------
# https://www.imdb.com/title/tt5215952/keywords
# -------------------- Scraping movie url 162/853 --------------------
# https://www.imdb.com/title/tt5220122/keywords
# -------------------- Scraping movie url 163/853 --------------------
# https://www.imdb.com/title/tt5238904/keywords
# -------------------- Scraping movie url 164/853 --------------------
# https://www.imdb.com/title/tt5247022/keywords
# -------------------- Scraping movie url 165/853 --------------------
# https://www.imdb.com/title/tt5247704/keywords
# -------------------- Scraping movie url 166/853 --------------------
# https://www.imdb.com/title/tt5259822/keywords
# -------------------- Scraping movie url 167/853 --------------------
# https://www.imdb.com/title/tt5269396/keywords
# -------------------- Scraping movie url 168/853 --------------------
# https://www.imdb.com/title/tt5287168/keywords
# -------------------- Scraping movie url 169/853 --------------------
# https://www.imdb.com/title/tt5294198/keywords
# -------------------- Scraping movie url 170/853 --------------------
# https://www.imdb.com/title/tt5294518/keywords
# -------------------- Scraping movie url 171/853 --------------------
# https://www.imdb.com/title/tt5294522/keywords
# -------------------- Scraping movie url 172/853 --------------------
# https://www.imdb.com/title/tt5294550/keywords
# -------------------- Scraping movie url 173/853 --------------------
# https://www.imdb.com/title/tt5297256/keywords
# -------------------- Scraping movie url 174/853 --------------------
# https://www.imdb.com/title/tt5301662/keywords
# -------------------- Scraping movie url 175/853 --------------------
# https://www.imdb.com/title/tt5308322/keywords
# -------------------- Scraping movie url 176/853 --------------------
# https://www.imdb.com/title/tt5310090/keywords
# -------------------- Scraping movie url 177/853 --------------------
# https://www.imdb.com/title/tt5311514/keywords
# -------------------- Scraping movie url 178/853 --------------------
# https://www.imdb.com/title/tt5312232/keywords
# -------------------- Scraping movie url 179/853 --------------------
# https://www.imdb.com/title/tt5314190/keywords
# -------------------- Scraping movie url 180/853 --------------------
# https://www.imdb.com/title/tt5316540/keywords
# -------------------- Scraping movie url 181/853 --------------------
# https://www.imdb.com/title/tt5322012/keywords
# -------------------- Scraping movie url 182/853 --------------------
# https://www.imdb.com/title/tt5325452/keywords
# -------------------- Scraping movie url 183/853 --------------------
# https://www.imdb.com/title/tt5360952/keywords
# -------------------- Scraping movie url 184/853 --------------------
# https://www.imdb.com/title/tt5362988/keywords
# -------------------- Scraping movie url 185/853 --------------------
# https://www.imdb.com/title/tt5363618/keywords
# -------------------- Scraping movie url 186/853 --------------------
# https://www.imdb.com/title/tt5372466/keywords
# -------------------- Scraping movie url 187/853 --------------------
# https://www.imdb.com/title/tt5390504/keywords
# -------------------- Scraping movie url 188/853 --------------------
# https://www.imdb.com/title/tt5420210/keywords
# -------------------- Scraping movie url 189/853 --------------------
# https://www.imdb.com/title/tt5431600/keywords
# -------------------- Scraping movie url 190/853 --------------------
# https://www.imdb.com/title/tt5433138/keywords
# -------------------- Scraping movie url 191/853 --------------------
# https://www.imdb.com/title/tt5439796/keywords
# -------------------- Scraping movie url 192/853 --------------------
# https://www.imdb.com/title/tt5439812/keywords
# -------------------- Scraping movie url 193/853 --------------------
# https://www.imdb.com/title/tt5442430/keywords
# -------------------- Scraping movie url 194/853 --------------------
# https://www.imdb.com/title/tt5442456/keywords
# -------------------- Scraping movie url 195/853 --------------------
# https://www.imdb.com/title/tt5457772/keywords
# -------------------- Scraping movie url 196/853 --------------------
# https://www.imdb.com/title/tt5458088/keywords
# -------------------- Scraping movie url 197/853 --------------------
# https://www.imdb.com/title/tt5460276/keywords
# -------------------- Scraping movie url 198/853 --------------------
# https://www.imdb.com/title/tt5461944/keywords
# -------------------- Scraping movie url 199/853 --------------------
# https://www.imdb.com/title/tt5462326/keywords
# -------------------- Scraping movie url 200/853 --------------------
# https://www.imdb.com/title/tt5462602/keywords
# -------------------- Scraping movie url 201/853 --------------------
# https://www.imdb.com/title/tt5463162/keywords
# -------------------- Scraping movie url 202/853 --------------------
# https://www.imdb.com/title/tt5466186/keywords
# -------------------- Scraping movie url 203/853 --------------------
# https://www.imdb.com/title/tt5474036/keywords
# -------------------- Scraping movie url 204/853 --------------------
# https://www.imdb.com/title/tt5478478/keywords
# -------------------- Scraping movie url 205/853 --------------------
# https://www.imdb.com/title/tt5501104/keywords
# -------------------- Scraping movie url 206/853 --------------------
# https://www.imdb.com/title/tt5503686/keywords
# -------------------- Scraping movie url 207/853 --------------------
# https://www.imdb.com/title/tt5516328/keywords
# -------------------- Scraping movie url 208/853 --------------------
# https://www.imdb.com/title/tt5519340/keywords
# -------------------- Scraping movie url 209/853 --------------------
# https://www.imdb.com/title/tt5523010/keywords
# -------------------- Scraping movie url 210/853 --------------------
# https://www.imdb.com/title/tt5534434/keywords
# -------------------- Scraping movie url 211/853 --------------------
# https://www.imdb.com/title/tt5540992/keywords
# -------------------- Scraping movie url 212/853 --------------------
# https://www.imdb.com/title/tt5556784/keywords
# -------------------- Scraping movie url 213/853 --------------------
# https://www.imdb.com/title/tt5563324/keywords
# -------------------- Scraping movie url 214/853 --------------------
# https://www.imdb.com/title/tt5571734/keywords
# -------------------- Scraping movie url 215/853 --------------------
# https://www.imdb.com/title/tt5577742/keywords
# -------------------- Scraping movie url 216/853 --------------------
# https://www.imdb.com/title/tt5580036/keywords
# -------------------- Scraping movie url 217/853 --------------------
# https://www.imdb.com/title/tt5580266/keywords
# -------------------- Scraping movie url 218/853 --------------------
# https://www.imdb.com/title/tt5580390/keywords
# -------------------- Scraping movie url 219/853 --------------------
# https://www.imdb.com/title/tt5592248/keywords
# -------------------- Scraping movie url 220/853 --------------------
# https://www.imdb.com/title/tt5592878/keywords
# -------------------- Scraping movie url 221/853 --------------------
# https://www.imdb.com/title/tt5598292/keywords
# -------------------- Scraping movie url 222/853 --------------------
# https://www.imdb.com/title/tt5600714/keywords
# -------------------- Scraping movie url 223/853 --------------------
# https://www.imdb.com/title/tt5606664/keywords
# -------------------- Scraping movie url 224/853 --------------------
# https://www.imdb.com/title/tt5607096/keywords
# -------------------- Scraping movie url 225/853 --------------------
# https://www.imdb.com/title/tt5610554/keywords
# -------------------- Scraping movie url 226/853 --------------------
# https://www.imdb.com/title/tt5612742/keywords
# -------------------- Scraping movie url 227/853 --------------------
# https://www.imdb.com/title/tt5619332/keywords
# -------------------- Scraping movie url 228/853 --------------------
# https://www.imdb.com/title/tt5628302/keywords
# -------------------- Scraping movie url 229/853 --------------------
# https://www.imdb.com/title/tt5635086/keywords
# -------------------- Scraping movie url 230/853 --------------------
# https://www.imdb.com/title/tt5638642/keywords
# -------------------- Scraping movie url 231/853 --------------------
# https://www.imdb.com/title/tt5649108/keywords
# -------------------- Scraping movie url 232/853 --------------------
# https://www.imdb.com/title/tt5649144/keywords
# -------------------- Scraping movie url 233/853 --------------------
# https://www.imdb.com/title/tt5653514/keywords
# -------------------- Scraping movie url 234/853 --------------------
# https://www.imdb.com/title/tt5657846/keywords
# -------------------- Scraping movie url 235/853 --------------------
# https://www.imdb.com/title/tt5657856/keywords
# -------------------- Scraping movie url 236/853 --------------------
# https://www.imdb.com/title/tt5662932/keywords
# -------------------- Scraping movie url 237/853 --------------------
# https://www.imdb.com/title/tt5664636/keywords
# -------------------- Scraping movie url 238/853 --------------------
# https://www.imdb.com/title/tt5666304/keywords
# -------------------- Scraping movie url 239/853 --------------------
# https://www.imdb.com/title/tt5668770/keywords
# -------------------- Scraping movie url 240/853 --------------------
# https://www.imdb.com/title/tt5670152/keywords
# -------------------- Scraping movie url 241/853 --------------------
# https://www.imdb.com/title/tt5688932/keywords
# -------------------- Scraping movie url 242/853 --------------------
# https://www.imdb.com/title/tt5690142/keywords
# -------------------- Scraping movie url 243/853 --------------------
# https://www.imdb.com/title/tt5690360/keywords
# -------------------- Scraping movie url 244/853 --------------------
# https://www.imdb.com/title/tt5691670/keywords
# -------------------- Scraping movie url 245/853 --------------------
# https://www.imdb.com/title/tt5697572/keywords
# -------------------- Scraping movie url 246/853 --------------------
# https://www.imdb.com/title/tt5700672/keywords
# -------------------- Scraping movie url 247/853 --------------------
# https://www.imdb.com/title/tt5709188/keywords
# -------------------- Scraping movie url 248/853 --------------------
# https://www.imdb.com/title/tt5711148/keywords
# -------------------- Scraping movie url 249/853 --------------------
# https://www.imdb.com/title/tt5713232/keywords
# -------------------- Scraping movie url 250/853 --------------------
# https://www.imdb.com/title/tt5715874/keywords
# -------------------- Scraping movie url 251/853 --------------------
# https://www.imdb.com/title/tt5716464/keywords
# -------------------- Scraping movie url 252/853 --------------------
# https://www.imdb.com/title/tt5719700/keywords
# -------------------- Scraping movie url 253/853 --------------------
# https://www.imdb.com/title/tt5719748/keywords
# -------------------- Scraping movie url 254/853 --------------------
# https://www.imdb.com/title/tt5723272/keywords
# -------------------- Scraping movie url 255/853 --------------------
# https://www.imdb.com/title/tt5723286/keywords
# -------------------- Scraping movie url 256/853 --------------------
# https://www.imdb.com/title/tt5726086/keywords
# -------------------- Scraping movie url 257/853 --------------------
# https://www.imdb.com/title/tt5726616/keywords
# -------------------- Scraping movie url 258/853 --------------------
# https://www.imdb.com/title/tt5727208/keywords
# -------------------- Scraping movie url 259/853 --------------------
# https://www.imdb.com/title/tt5729348/keywords
# -------------------- Scraping movie url 260/853 --------------------
# https://www.imdb.com/title/tt5734576/keywords
# -------------------- Scraping movie url 261/853 --------------------
# https://www.imdb.com/title/tt5737862/keywords
# -------------------- Scraping movie url 262/853 --------------------
# https://www.imdb.com/title/tt5742374/keywords
# -------------------- Scraping movie url 263/853 --------------------
# https://www.imdb.com/title/tt5748448/keywords
# -------------------- Scraping movie url 264/853 --------------------
# https://www.imdb.com/title/tt5758778/keywords
# -------------------- Scraping movie url 265/853 --------------------
# https://www.imdb.com/title/tt5774060/keywords
# -------------------- Scraping movie url 266/853 --------------------
# https://www.imdb.com/title/tt5774450/keywords
# -------------------- Scraping movie url 267/853 --------------------
# https://www.imdb.com/title/tt5776858/keywords
# -------------------- Scraping movie url 268/853 --------------------
# https://www.imdb.com/title/tt5814060/keywords
# -------------------- Scraping movie url 269/853 --------------------
# https://www.imdb.com/title/tt5814534/keywords
# -------------------- Scraping movie url 270/853 --------------------
# https://www.imdb.com/title/tt5814592/keywords
# -------------------- Scraping movie url 271/853 --------------------
# https://www.imdb.com/title/tt5816682/keywords
# -------------------- Scraping movie url 272/853 --------------------
# https://www.imdb.com/title/tt5822564/keywords
# -------------------- Scraping movie url 273/853 --------------------
# https://www.imdb.com/title/tt5825380/keywords
# -------------------- Scraping movie url 274/853 --------------------
# https://www.imdb.com/title/tt5827916/keywords
# -------------------- Scraping movie url 275/853 --------------------
# https://www.imdb.com/title/tt5834262/keywords
# -------------------- Scraping movie url 276/853 --------------------
# https://www.imdb.com/title/tt5843876/keywords
# -------------------- Scraping movie url 277/853 --------------------
# https://www.imdb.com/title/tt5848272/keywords
# -------------------- Scraping movie url 278/853 --------------------
# https://www.imdb.com/title/tt5848416/keywords
# -------------------- Scraping movie url 279/853 --------------------
# https://www.imdb.com/title/tt5855772/keywords
# -------------------- Scraping movie url 280/853 --------------------
# https://www.imdb.com/title/tt5859238/keywords
# -------------------- Scraping movie url 281/853 --------------------
# https://www.imdb.com/title/tt5859882/keywords
# -------------------- Scraping movie url 282/853 --------------------
# https://www.imdb.com/title/tt5862166/keywords
# -------------------- Scraping movie url 283/853 --------------------
# https://www.imdb.com/title/tt5862312/keywords
# -------------------- Scraping movie url 284/853 --------------------
# https://www.imdb.com/title/tt5867314/keywords
# -------------------- Scraping movie url 285/853 --------------------
# https://www.imdb.com/title/tt5871080/keywords
# -------------------- Scraping movie url 286/853 --------------------
# https://www.imdb.com/title/tt5882970/keywords
# -------------------- Scraping movie url 287/853 --------------------
# https://www.imdb.com/title/tt5884052/keywords
# -------------------- Scraping movie url 288/853 --------------------
# https://www.imdb.com/title/tt5886046/keywords
# -------------------- Scraping movie url 289/853 --------------------
# https://www.imdb.com/title/tt5886440/keywords
# -------------------- Scraping movie url 290/853 --------------------
# https://www.imdb.com/title/tt5892746/keywords
# -------------------- Scraping movie url 291/853 --------------------
# https://www.imdb.com/title/tt5913798/keywords
# -------------------- Scraping movie url 292/853 --------------------
# https://www.imdb.com/title/tt5918982/keywords
# -------------------- Scraping movie url 293/853 --------------------
# https://www.imdb.com/title/tt5929750/keywords
# -------------------- Scraping movie url 294/853 --------------------
# https://www.imdb.com/title/tt5935704/keywords
# -------------------- Scraping movie url 295/853 --------------------
# https://www.imdb.com/title/tt5941692/keywords
# -------------------- Scraping movie url 296/853 --------------------
# https://www.imdb.com/title/tt5956100/keywords
# -------------------- Scraping movie url 297/853 --------------------
# https://www.imdb.com/title/tt5962210/keywords
# -------------------- Scraping movie url 298/853 --------------------
# https://www.imdb.com/title/tt5968394/keywords
# -------------------- Scraping movie url 299/853 --------------------
# https://www.imdb.com/title/tt5989218/keywords
# -------------------- Scraping movie url 300/853 --------------------
# https://www.imdb.com/title/tt5990066/keywords
# -------------------- Scraping movie url 301/853 --------------------
# https://www.imdb.com/title/tt5996202/keywords
# -------------------- Scraping movie url 302/853 --------------------
# https://www.imdb.com/title/tt6000478/keywords
# -------------------- Scraping movie url 303/853 --------------------
# https://www.imdb.com/title/tt6003368/keywords
# -------------------- Scraping movie url 304/853 --------------------
# https://www.imdb.com/title/tt6017756/keywords
# -------------------- Scraping movie url 305/853 --------------------
# https://www.imdb.com/title/tt6017942/keywords
# -------------------- Scraping movie url 306/853 --------------------
# https://www.imdb.com/title/tt6040662/keywords
# -------------------- Scraping movie url 307/853 --------------------
# https://www.imdb.com/title/tt6048922/keywords
# -------------------- Scraping movie url 308/853 --------------------
# https://www.imdb.com/title/tt6053438/keywords
# -------------------- Scraping movie url 309/853 --------------------
# https://www.imdb.com/title/tt6053938/keywords
# -------------------- Scraping movie url 310/853 --------------------
# https://www.imdb.com/title/tt6054846/keywords
# -------------------- Scraping movie url 311/853 --------------------
# https://www.imdb.com/title/tt6063050/keywords
# -------------------- Scraping movie url 312/853 --------------------
# https://www.imdb.com/title/tt6079516/keywords
# -------------------- Scraping movie url 313/853 --------------------
# https://www.imdb.com/title/tt6079772/keywords
# -------------------- Scraping movie url 314/853 --------------------
# https://www.imdb.com/title/tt6089700/keywords
# -------------------- Scraping movie url 315/853 --------------------
# https://www.imdb.com/title/tt6095472/keywords
# -------------------- Scraping movie url 316/853 --------------------
# https://www.imdb.com/title/tt6105098/keywords
# -------------------- Scraping movie url 317/853 --------------------
# https://www.imdb.com/title/tt6107548/keywords
# -------------------- Scraping movie url 318/853 --------------------
# https://www.imdb.com/title/tt6108090/keywords
# -------------------- Scraping movie url 319/853 --------------------
# https://www.imdb.com/title/tt6108178/keywords
# -------------------- Scraping movie url 320/853 --------------------
# https://www.imdb.com/title/tt6111574/keywords
# -------------------- Scraping movie url 321/853 --------------------
# https://www.imdb.com/title/tt6113488/keywords
# -------------------- Scraping movie url 322/853 --------------------
# https://www.imdb.com/title/tt6116856/keywords
# -------------------- Scraping movie url 323/853 --------------------
# https://www.imdb.com/title/tt6118340/keywords
# -------------------- Scraping movie url 324/853 --------------------
# https://www.imdb.com/title/tt6127004/keywords
# -------------------- Scraping movie url 325/853 --------------------
# https://www.imdb.com/title/tt6129302/keywords
# -------------------- Scraping movie url 326/853 --------------------
# https://www.imdb.com/title/tt6131450/keywords
# -------------------- Scraping movie url 327/853 --------------------
# https://www.imdb.com/title/tt6133130/keywords
# -------------------- Scraping movie url 328/853 --------------------
# https://www.imdb.com/title/tt6133466/keywords
# -------------------- Scraping movie url 329/853 --------------------
# https://www.imdb.com/title/tt6138228/keywords
# -------------------- Scraping movie url 330/853 --------------------
# https://www.imdb.com/title/tt6139732/keywords
# -------------------- Scraping movie url 331/853 --------------------
# https://www.imdb.com/title/tt6141246/keywords
# -------------------- Scraping movie url 332/853 --------------------
# https://www.imdb.com/title/tt6143850/keywords
# -------------------- Scraping movie url 333/853 --------------------
# https://www.imdb.com/title/tt6146586/keywords
# -------------------- Scraping movie url 334/853 --------------------
# https://www.imdb.com/title/tt6148156/keywords
# -------------------- Scraping movie url 335/853 --------------------
# https://www.imdb.com/title/tt6155172/keywords
# -------------------- Scraping movie url 336/853 --------------------
# https://www.imdb.com/title/tt6169694/keywords
# -------------------- Scraping movie url 337/853 --------------------
# https://www.imdb.com/title/tt6182908/keywords
# -------------------- Scraping movie url 338/853 --------------------
# https://www.imdb.com/title/tt6189022/keywords
# -------------------- Scraping movie url 339/853 --------------------
# https://www.imdb.com/title/tt6195094/keywords
# -------------------- Scraping movie url 340/853 --------------------
# https://www.imdb.com/title/tt6204340/keywords
# -------------------- Scraping movie url 341/853 --------------------
# https://www.imdb.com/title/tt6205872/keywords
# -------------------- Scraping movie url 342/853 --------------------
# https://www.imdb.com/title/tt6206564/keywords
# -------------------- Scraping movie url 343/853 --------------------
# https://www.imdb.com/title/tt6210996/keywords
# -------------------- Scraping movie url 344/853 --------------------
# https://www.imdb.com/title/tt6213362/keywords
# -------------------- Scraping movie url 345/853 --------------------
# https://www.imdb.com/title/tt6214928/keywords
# -------------------- Scraping movie url 346/853 --------------------
# https://www.imdb.com/title/tt6217306/keywords
# -------------------- Scraping movie url 347/853 --------------------
# https://www.imdb.com/title/tt6217804/keywords
# -------------------- Scraping movie url 348/853 --------------------
# https://www.imdb.com/title/tt6217926/keywords
# -------------------- Scraping movie url 349/853 --------------------
# https://www.imdb.com/title/tt6218358/keywords
# -------------------- Scraping movie url 350/853 --------------------
# https://www.imdb.com/title/tt6222118/keywords
# -------------------- Scraping movie url 351/853 --------------------
# https://www.imdb.com/title/tt6225520/keywords
# -------------------- Scraping movie url 352/853 --------------------
# https://www.imdb.com/title/tt6246322/keywords
# -------------------- Scraping movie url 353/853 --------------------
# https://www.imdb.com/title/tt6257174/keywords
# -------------------- Scraping movie url 354/853 --------------------
# https://www.imdb.com/title/tt6259380/keywords
# -------------------- Scraping movie url 355/853 --------------------
# https://www.imdb.com/title/tt6264654/keywords
# -------------------- Scraping movie url 356/853 --------------------
# https://www.imdb.com/title/tt6264938/keywords
# -------------------- Scraping movie url 357/853 --------------------
# https://www.imdb.com/title/tt6265828/keywords
# -------------------- Scraping movie url 358/853 --------------------
# https://www.imdb.com/title/tt6266538/keywords
# -------------------- Scraping movie url 359/853 --------------------
# https://www.imdb.com/title/tt6272828/keywords
# -------------------- Scraping movie url 360/853 --------------------
# https://www.imdb.com/title/tt6277440/keywords
# -------------------- Scraping movie url 361/853 --------------------
# https://www.imdb.com/title/tt6285944/keywords
# -------------------- Scraping movie url 362/853 --------------------
# https://www.imdb.com/title/tt6288124/keywords
# -------------------- Scraping movie url 363/853 --------------------
# https://www.imdb.com/title/tt6288250/keywords
# -------------------- Scraping movie url 364/853 --------------------
# https://www.imdb.com/title/tt6288694/keywords
# -------------------- Scraping movie url 365/853 --------------------
# https://www.imdb.com/title/tt6292852/keywords
# -------------------- Scraping movie url 366/853 --------------------
# https://www.imdb.com/title/tt6294822/keywords
# -------------------- Scraping movie url 367/853 --------------------
# https://www.imdb.com/title/tt6294892/keywords
# -------------------- Scraping movie url 368/853 --------------------
# https://www.imdb.com/title/tt6296236/keywords
# -------------------- Scraping movie url 369/853 --------------------
# https://www.imdb.com/title/tt6304046/keywords
# -------------------- Scraping movie url 370/853 --------------------
# https://www.imdb.com/title/tt6304162/keywords
# -------------------- Scraping movie url 371/853 --------------------
# https://www.imdb.com/title/tt6306064/keywords
# -------------------- Scraping movie url 372/853 --------------------
# https://www.imdb.com/title/tt6320628/keywords
# -------------------- Scraping movie url 373/853 --------------------
# https://www.imdb.com/title/tt6324278/keywords
# -------------------- Scraping movie url 374/853 --------------------
# https://www.imdb.com/title/tt6334354/keywords
# -------------------- Scraping movie url 375/853 --------------------
# https://www.imdb.com/title/tt6336356/keywords
# -------------------- Scraping movie url 376/853 --------------------
# https://www.imdb.com/title/tt6341832/keywords
# -------------------- Scraping movie url 377/853 --------------------
# https://www.imdb.com/title/tt6343314/keywords
# -------------------- Scraping movie url 378/853 --------------------
# https://www.imdb.com/title/tt6359956/keywords
# -------------------- Scraping movie url 379/853 --------------------
# https://www.imdb.com/title/tt6378710/keywords
# -------------------- Scraping movie url 380/853 --------------------
# https://www.imdb.com/title/tt6394270/keywords
# -------------------- Scraping movie url 381/853 --------------------
# https://www.imdb.com/title/tt6398184/keywords
# -------------------- Scraping movie url 382/853 --------------------
# https://www.imdb.com/title/tt6401004/keywords
# -------------------- Scraping movie url 383/853 --------------------
# https://www.imdb.com/title/tt6402468/keywords
# -------------------- Scraping movie url 384/853 --------------------
# https://www.imdb.com/title/tt6412452/keywords
# -------------------- Scraping movie url 385/853 --------------------
# https://www.imdb.com/title/tt6421110/keywords
# -------------------- Scraping movie url 386/853 --------------------
# https://www.imdb.com/title/tt6423362/keywords
# -------------------- Scraping movie url 387/853 --------------------
# https://www.imdb.com/title/tt6428676/keywords
# -------------------- Scraping movie url 388/853 --------------------
# https://www.imdb.com/title/tt6433832/keywords
# -------------------- Scraping movie url 389/853 --------------------
# https://www.imdb.com/title/tt6439020/keywords
# -------------------- Scraping movie url 390/853 --------------------
# https://www.imdb.com/title/tt6450186/keywords
# -------------------- Scraping movie url 391/853 --------------------
# https://www.imdb.com/title/tt6450804/keywords
# -------------------- Scraping movie url 392/853 --------------------
# https://www.imdb.com/title/tt6452574/keywords
# -------------------- Scraping movie url 393/853 --------------------
# https://www.imdb.com/title/tt6472976/keywords
# -------------------- Scraping movie url 394/853 --------------------
# https://www.imdb.com/title/tt6474040/keywords
# -------------------- Scraping movie url 395/853 --------------------
# https://www.imdb.com/title/tt6475714/keywords
# -------------------- Scraping movie url 396/853 --------------------
# https://www.imdb.com/title/tt6484982/keywords
# -------------------- Scraping movie url 397/853 --------------------
# https://www.imdb.com/title/tt6485666/keywords
# -------------------- Scraping movie url 398/853 --------------------
# https://www.imdb.com/title/tt6491178/keywords
# -------------------- Scraping movie url 399/853 --------------------
# https://www.imdb.com/title/tt6495770/keywords
# -------------------- Scraping movie url 400/853 --------------------
# https://www.imdb.com/title/tt6499752/keywords
# -------------------- Scraping movie url 401/853 --------------------
# https://www.imdb.com/title/tt6511932/keywords
# -------------------- Scraping movie url 402/853 --------------------
# https://www.imdb.com/title/tt6513120/keywords
# -------------------- Scraping movie url 403/853 --------------------
# https://www.imdb.com/title/tt6521876/keywords
# -------------------- Scraping movie url 404/853 --------------------
# https://www.imdb.com/title/tt6522546/keywords
# -------------------- Scraping movie url 405/853 --------------------
# https://www.imdb.com/title/tt6523720/keywords
# -------------------- Scraping movie url 406/853 --------------------
# https://www.imdb.com/title/tt6533240/keywords
# -------------------- Scraping movie url 407/853 --------------------
# https://www.imdb.com/title/tt6535880/keywords
# -------------------- Scraping movie url 408/853 --------------------
# https://www.imdb.com/title/tt6543652/keywords
# -------------------- Scraping movie url 409/853 --------------------
# https://www.imdb.com/title/tt6560164/keywords
# -------------------- Scraping movie url 410/853 --------------------
# https://www.imdb.com/title/tt6565702/keywords
# -------------------- Scraping movie url 411/853 --------------------
# https://www.imdb.com/title/tt6566576/keywords
# -------------------- Scraping movie url 412/853 --------------------
# https://www.imdb.com/title/tt6566768/keywords
# -------------------- Scraping movie url 413/853 --------------------
# https://www.imdb.com/title/tt6571548/keywords
# -------------------- Scraping movie url 414/853 --------------------
# https://www.imdb.com/title/tt6574146/keywords
# -------------------- Scraping movie url 415/853 --------------------
# https://www.imdb.com/title/tt6574272/keywords
# -------------------- Scraping movie url 416/853 --------------------
# https://www.imdb.com/title/tt6587640/keywords
# -------------------- Scraping movie url 417/853 --------------------
# https://www.imdb.com/title/tt6588966/keywords
# -------------------- Scraping movie url 418/853 --------------------
# https://www.imdb.com/title/tt6595896/keywords
# ...
# -------------------- Scraping movie url 716/853 --------------------
# https://www.imdb.com/title/tt9150970/keywords
# -------------------- Scraping movie url 717/853 --------------------
# https://www.imdb.com/title/tt9173418/keywords
# -------------------- Scraping movie url 718/853 --------------------
# https://www.imdb.com/title/tt9177040/keywords
# -------------------- Scraping movie url 719/853 --------------------
# https://www.imdb.com/title/tt9203694/keywords
# -------------------- Scraping movie url 720/853 --------------------
# https://www.imdb.com/title/tt9207700/keywords
# -------------------- Scraping movie url 721/853 --------------------
# https://www.imdb.com/title/tt9214832/keywords
# -------------------- Scraping movie url 722/853 --------------------
# https://www.imdb.com/title/tt9243804/keywords
# -------------------- Scraping movie url 723/853 --------------------
# https://www.imdb.com/title/tt9243946/keywords
# -------------------- Scraping movie url 724/853 --------------------
# https://www.imdb.com/title/tt9264728/keywords
# -------------------- Scraping movie url 725/853 --------------------
# https://www.imdb.com/title/tt9308382/keywords
# -------------------- Scraping movie url 726/853 --------------------
# https://www.imdb.com/title/tt9340860/keywords
# -------------------- Scraping movie url 727/853 --------------------
# https://www.imdb.com/title/tt9347730/keywords
# -------------------- Scraping movie url 728/853 --------------------
# https://www.imdb.com/title/tt9354842/keywords
# -------------------- Scraping movie url 729/853 --------------------
# https://www.imdb.com/title/tt9354944/keywords
# -------------------- Scraping movie url 730/853 --------------------
# https://www.imdb.com/title/tt9356952/keywords
# -------------------- Scraping movie url 731/853 --------------------
# https://www.imdb.com/title/tt9359344/keywords
# -------------------- Scraping movie url 732/853 --------------------
# https://www.imdb.com/title/tt9376612/keywords
# -------------------- Scraping movie url 733/853 --------------------
# https://www.imdb.com/title/tt9387250/keywords
# -------------------- Scraping movie url 734/853 --------------------
# https://www.imdb.com/title/tt9419834/keywords
# -------------------- Scraping movie url 735/853 --------------------
# https://www.imdb.com/title/tt9421570/keywords
# -------------------- Scraping movie url 736/853 --------------------
# https://www.imdb.com/title/tt9484998/keywords
# -------------------- Scraping movie url 737/853 --------------------
# https://www.imdb.com/title/tt9580138/keywords
# -------------------- Scraping movie url 738/853 --------------------
# https://www.imdb.com/title/tt9581076/keywords
# -------------------- Scraping movie url 739/853 --------------------
# https://www.imdb.com/title/tt9616700/keywords
# -------------------- Scraping movie url 740/853 --------------------
# https://www.imdb.com/title/tt9620292/keywords
# -------------------- Scraping movie url 741/853 --------------------
# https://www.imdb.com/title/tt9625664/keywords
# -------------------- Scraping movie url 742/853 --------------------
# https://www.imdb.com/title/tt9639470/keywords
# -------------------- Scraping movie url 743/853 --------------------
# https://www.imdb.com/title/tt9648886/keywords
# -------------------- Scraping movie url 744/853 --------------------
# https://www.imdb.com/title/tt9686708/keywords
# -------------------- Scraping movie url 745/853 --------------------
# https://www.imdb.com/title/tt9689696/keywords
# -------------------- Scraping movie url 746/853 --------------------
# https://www.imdb.com/title/tt9695722/keywords
# -------------------- Scraping movie url 747/853 --------------------
# https://www.imdb.com/title/tt9701940/keywords
# -------------------- Scraping movie url 748/853 --------------------
# https://www.imdb.com/title/tt9731534/keywords
# -------------------- Scraping movie url 749/853 --------------------
# https://www.imdb.com/title/tt9738716/keywords
# -------------------- Scraping movie url 750/853 --------------------
# https://www.imdb.com/title/tt9770150/keywords
# -------------------- Scraping movie url 751/853 --------------------
# https://www.imdb.com/title/tt9777644/keywords
# -------------------- Scraping movie url 752/853 --------------------
# https://www.imdb.com/title/tt9777666/keywords
# -------------------- Scraping movie url 753/853 --------------------
# https://www.imdb.com/title/tt9784798/keywords
# -------------------- Scraping movie url 754/853 --------------------
# https://www.imdb.com/title/tt9815714/keywords
# -------------------- Scraping movie url 755/853 --------------------
# https://www.imdb.com/title/tt9820556/keywords
# -------------------- Scraping movie url 756/853 --------------------
# https://www.imdb.com/title/tt9831136/keywords
# -------------------- Scraping movie url 757/853 --------------------
# https://www.imdb.com/title/tt9844522/keywords
# -------------------- Scraping movie url 758/853 --------------------
# https://www.imdb.com/title/tt9845110/keywords
# -------------------- Scraping movie url 759/853 --------------------
# https://www.imdb.com/title/tt9877170/keywords
# -------------------- Scraping movie url 760/853 --------------------
# https://www.imdb.com/title/tt9893250/keywords
# -------------------- Scraping movie url 761/853 --------------------
# https://www.imdb.com/title/tt9916362/keywords
# -------------------- Scraping movie url 762/853 --------------------
# https://www.imdb.com/title/tt10003008/keywords
# -------------------- Scraping movie url 763/853 --------------------
# https://www.imdb.com/title/tt10016180/keywords
# -------------------- Scraping movie url 764/853 --------------------
# https://www.imdb.com/title/tt10039344/keywords
# -------------------- Scraping movie url 765/853 --------------------
# https://www.imdb.com/title/tt10059518/keywords
# -------------------- Scraping movie url 766/853 --------------------
# https://www.imdb.com/title/tt10062556/keywords
# -------------------- Scraping movie url 767/853 --------------------
# https://www.imdb.com/title/tt10065694/keywords
# -------------------- Scraping movie url 768/853 --------------------
# https://www.imdb.com/title/tt10126434/keywords
# -------------------- Scraping movie url 769/853 --------------------
# https://www.imdb.com/title/tt10199590/keywords
# -------------------- Scraping movie url 770/853 --------------------
# https://www.imdb.com/title/tt10208198/keywords
# -------------------- Scraping movie url 771/853 --------------------
# https://www.imdb.com/title/tt10228134/keywords
# -------------------- Scraping movie url 772/853 --------------------
# https://www.imdb.com/title/tt10228168/keywords
# -------------------- Scraping movie url 773/853 --------------------
# https://www.imdb.com/title/tt10230994/keywords
# -------------------- Scraping movie url 774/853 --------------------
# https://www.imdb.com/title/tt10243992/keywords
# -------------------- Scraping movie url 775/853 --------------------
# https://www.imdb.com/title/tt10272386/keywords
# -------------------- Scraping movie url 776/853 --------------------
# https://www.imdb.com/title/tt10274284/keywords
# -------------------- Scraping movie url 777/853 --------------------
# https://www.imdb.com/title/tt10288566/keywords
# -------------------- Scraping movie url 778/853 --------------------
# https://www.imdb.com/title/tt10295212/keywords
# -------------------- Scraping movie url 779/853 --------------------
# https://www.imdb.com/title/tt10303430/keywords
# -------------------- Scraping movie url 780/853 --------------------
# https://www.imdb.com/title/tt10308928/keywords
# -------------------- Scraping movie url 781/853 --------------------
# https://www.imdb.com/title/tt10309552/keywords
# -------------------- Scraping movie url 782/853 --------------------
# https://www.imdb.com/title/tt10309902/keywords
# -------------------- Scraping movie url 783/853 --------------------
# https://www.imdb.com/title/tt10314450/keywords
# -------------------- Scraping movie url 784/853 --------------------
# https://www.imdb.com/title/tt10327252/keywords
# -------------------- Scraping movie url 785/853 --------------------
# https://www.imdb.com/title/tt10329134/keywords
# -------------------- Scraping movie url 786/853 --------------------
# https://www.imdb.com/title/tt10342730/keywords
# -------------------- Scraping movie url 787/853 --------------------
# https://www.imdb.com/title/tt10358198/keywords
# -------------------- Scraping movie url 788/853 --------------------
# https://www.imdb.com/title/tt10366460/keywords
# -------------------- Scraping movie url 789/853 --------------------
# https://www.imdb.com/title/tt10384744/keywords
# -------------------- Scraping movie url 790/853 --------------------
# https://www.imdb.com/title/tt10451852/keywords
# -------------------- Scraping movie url 791/853 --------------------
# https://www.imdb.com/title/tt10451914/keywords
# -------------------- Scraping movie url 792/853 --------------------
# https://www.imdb.com/title/tt10481868/keywords
# -------------------- Scraping movie url 793/853 --------------------
# https://www.imdb.com/title/tt10514222/keywords
# -------------------- Scraping movie url 794/853 --------------------
# https://www.imdb.com/title/tt10530176/keywords
# -------------------- Scraping movie url 795/853 --------------------
# https://www.imdb.com/title/tt10539608/keywords
# -------------------- Scraping movie url 796/853 --------------------
# https://www.imdb.com/title/tt10589914/keywords
# -------------------- Scraping movie url 797/853 --------------------
# https://www.imdb.com/title/tt10618286/keywords
# -------------------- Scraping movie url 798/853 --------------------
# https://www.imdb.com/title/tt10633456/keywords
# -------------------- Scraping movie url 799/853 --------------------
# https://www.imdb.com/title/tt10665338/keywords
# -------------------- Scraping movie url 800/853 --------------------
# https://www.imdb.com/title/tt10676012/keywords
# -------------------- Scraping movie url 801/853 --------------------
# https://www.imdb.com/title/tt10682266/keywords
# -------------------- Scraping movie url 802/853 --------------------
# https://www.imdb.com/title/tt10696784/keywords
# -------------------- Scraping movie url 803/853 --------------------
# https://www.imdb.com/title/tt10696896/keywords
# -------------------- Scraping movie url 804/853 --------------------
# https://www.imdb.com/title/tt10731768/keywords
# -------------------- Scraping movie url 805/853 --------------------
# https://www.imdb.com/title/tt10805432/keywords
# -------------------- Scraping movie url 806/853 --------------------
# https://www.imdb.com/title/tt10831086/keywords
# -------------------- Scraping movie url 807/853 --------------------
# https://www.imdb.com/title/tt10886166/keywords
# -------------------- Scraping movie url 808/853 --------------------
# https://www.imdb.com/title/tt10901588/keywords
# -------------------- Scraping movie url 809/853 --------------------
# https://www.imdb.com/title/tt10919380/keywords
# -------------------- Scraping movie url 810/853 --------------------
# https://www.imdb.com/title/tt10944486/keywords
# -------------------- Scraping movie url 811/853 --------------------
# https://www.imdb.com/title/tt10944760/keywords
# -------------------- Scraping movie url 812/853 --------------------
# https://www.imdb.com/title/tt10952782/keywords
# -------------------- Scraping movie url 813/853 --------------------
# https://www.imdb.com/title/tt10954652/keywords
# -------------------- Scraping movie url 814/853 --------------------
# https://www.imdb.com/title/tt10955148/keywords
# -------------------- Scraping movie url 815/853 --------------------
# https://www.imdb.com/title/tt10962368/keywords
# -------------------- Scraping movie url 816/853 --------------------
# https://www.imdb.com/title/tt10978398/keywords
# -------------------- Scraping movie url 817/853 --------------------
# https://www.imdb.com/title/tt11003218/keywords
# -------------------- Scraping movie url 818/853 --------------------
# https://www.imdb.com/title/tt11024272/keywords
# -------------------- Scraping movie url 819/853 --------------------
# https://www.imdb.com/title/tt11057644/keywords
# -------------------- Scraping movie url 820/853 --------------------
# https://www.imdb.com/title/tt11083552/keywords
# -------------------- Scraping movie url 821/853 --------------------
# https://www.imdb.com/title/tt11121664/keywords
# -------------------- Scraping movie url 822/853 --------------------
# https://www.imdb.com/title/tt11125620/keywords
# -------------------- Scraping movie url 823/853 --------------------
# https://www.imdb.com/title/tt11161474/keywords
# -------------------- Scraping movie url 824/853 --------------------
# https://www.imdb.com/title/tt11188624/keywords
# -------------------- Scraping movie url 825/853 --------------------
# https://www.imdb.com/title/tt11196036/keywords
# -------------------- Scraping movie url 826/853 --------------------
# https://www.imdb.com/title/tt11260832/keywords
# -------------------- Scraping movie url 827/853 --------------------
# https://www.imdb.com/title/tt11317142/keywords
# -------------------- Scraping movie url 828/853 --------------------
# https://www.imdb.com/title/tt11327514/keywords
# -------------------- Scraping movie url 829/853 --------------------
# https://www.imdb.com/title/tt11390036/keywords
# -------------------- Scraping movie url 830/853 --------------------
# https://www.imdb.com/title/tt11456054/keywords
# -------------------- Scraping movie url 831/853 --------------------
# https://www.imdb.com/title/tt11525644/keywords
# -------------------- Scraping movie url 832/853 --------------------
# https://www.imdb.com/title/tt11648514/keywords
# -------------------- Scraping movie url 833/853 --------------------
# https://www.imdb.com/title/tt11651796/keywords
# -------------------- Scraping movie url 834/853 --------------------
# https://www.imdb.com/title/tt11657662/keywords
# -------------------- Scraping movie url 835/853 --------------------
# https://www.imdb.com/title/tt11750282/keywords
# -------------------- Scraping movie url 836/853 --------------------
# https://www.imdb.com/title/tt11762434/keywords
# -------------------- Scraping movie url 837/853 --------------------
# https://www.imdb.com/title/tt12036052/keywords
# -------------------- Scraping movie url 838/853 --------------------
# https://www.imdb.com/title/tt12108622/keywords
# -------------------- Scraping movie url 839/853 --------------------
# https://www.imdb.com/title/tt12137964/keywords
# -------------------- Scraping movie url 840/853 --------------------
# https://www.imdb.com/title/tt12274228/keywords
# -------------------- Scraping movie url 841/853 --------------------
# https://www.imdb.com/title/tt12361178/keywords
# -------------------- Scraping movie url 842/853 --------------------
# https://www.imdb.com/title/tt12361974/keywords
# -------------------- Scraping movie url 843/853 --------------------
# https://www.imdb.com/title/tt12676326/keywords
# -------------------- Scraping movie url 844/853 --------------------
# https://www.imdb.com/title/tt12677092/keywords
# -------------------- Scraping movie url 845/853 --------------------
# https://www.imdb.com/title/tt12731980/keywords
# -------------------- Scraping movie url 846/853 --------------------
# https://www.imdb.com/title/tt12763920/keywords
# -------------------- Scraping movie url 847/853 --------------------
# https://www.imdb.com/title/tt12801262/keywords
# -------------------- Scraping movie url 848/853 --------------------
# https://www.imdb.com/title/tt12838766/keywords
# -------------------- Scraping movie url 849/853 --------------------
# https://www.imdb.com/title/tt12986942/keywords
# -------------------- Scraping movie url 850/853 --------------------
# https://www.imdb.com/title/tt13061914/keywords
# -------------------- Scraping movie url 851/853 --------------------
# https://www.imdb.com/title/tt13095604/keywords
# -------------------- Scraping movie url 852/853 --------------------
# https://www.imdb.com/title/tt13354204/keywords
# -------------------- Scraping movie url 853/853 --------------------
# https://www.imdb.com/title/tt13491620/keywords

# %%
fileList = glob.glob("../movieFileTags/*.txt")
activeMovs = []
for i in fileList:
    activeMovs.append(i.replace('../movieFileTags/','').replace('.txt',''))
    
df_act_movs = pd.DataFrame(activeMovs)
df_act_movs.columns = ['tconst']
df_act_movs.head()
# Out:
#       tconst
# 0  tt0250687
# 1  tt0405393
# 2  tt2318092
# 3  tt0118647
# 4  tt0101316

# %%
print(len(actors))
actors = actors.merge(df_act_movs,how='inner')
print(len(actors))
# Out:
# 28176
# 26755

# %% [markdown]
# # Prepare actors list for scraped movies

# %%
print(len(actors))
actors.to_csv('../files/actors.csv',header=True,index=False)
actors.head()
# Out:
# 26755
#       nconst    primaryName     tconst
# 0  nm0000004   John Belushi  tt0077975
# 1  nm0000261    Karen Allen  tt0077975
# 2  nm0001371      Tom Hulce  tt0077975
# 3  nm0299122  Stephen Furst  tt0077975
# 4  nm0000004   John Belushi  tt0078723

# %%
print(len(df_act_movs))
# Out:
# 8471

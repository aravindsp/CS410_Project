# %% [markdown]
# # Download name.basics.tsv ad Read

# %%
import pandas as pd
actors = pd.read_csv('/Users/apillai2/Downloads/name.basics.tsv', sep='\t', header=0)

# %%
actors.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0031983,tt0072308,tt0050419,tt0053137
# 1  tt0037382,tt0117057,tt0038355,tt0071877
# 2  tt0057345,tt0056404,tt0054452,tt0049189
# 3  tt0072562,tt0080455,tt0078723,tt0077975
# 4  tt0050976,tt0060827,tt0083922,tt0050986

# %%
len(actors)
# Out:
# 11359935

# %% [markdown]
# # Apply Filters

# %%
actors = actors[(actors.birthYear > '1960') & (actors.primaryProfession.str.contains('act'))]
actors['titleCount'] = actors['knownForTitles'].str.count(',')+1
actors = actors[(actors.titleCount > 3)]
print(len(actors))
actors = actors[0:100]
actors = actors.reset_index(drop=True)
print(len(actors))
actors.head()
# Out:
# 771701
# 100
#       nconst       primaryName birthYear deathYear  \
# 0  nm0000084           Gong Li      1965        \N
# 1  nm0000093         Brad Pitt      1963        \N
# 2  nm0000096  Gillian Anderson      1968        \N
# 3  nm0000097   Pamela Anderson      1967        \N
# 4  nm0000098  Jennifer Aniston      1969        \N
#
#              primaryProfession                           knownForTitles  \
# 0                      actress  tt0101640,tt0430357,tt0397535,tt0473444
# 1    actor,producer,soundtrack  tt0114746,tt1210166,tt0356910,tt2935510
# 2  actress,producer,soundtrack  tt0106179,tt2294189,tt0455590,tt0442632
# 3    actress,producer,director  tt0115624,tt0267913,tt0306047,tt0426592
# 4  actress,producer,soundtrack  tt1723121,tt0279113,tt0108778,tt3442006
#
#    titleCount
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4

# %% [markdown]
# # Check Samples

# %%
actors[actors.primaryName.str.contains('Brad Pitt')]
# Out:
#       nconst primaryName birthYear deathYear          primaryProfession  \
# 1  nm0000093   Brad Pitt      1963        \N  actor,producer,soundtrack
#
#                             knownForTitles  titleCount
# 1  tt0114746,tt1210166,tt0356910,tt2935510           4

# %%
actors[actors.primaryName.str.contains('Chris Nolan')]
# Out:
# Empty DataFrame
# Columns: [nconst, primaryName, birthYear, deathYear, primaryProfession, knownForTitles, titleCount]
# Index: []

# %% [markdown]
# # Get Unique Titles for Actors

# %%
allTitles = ['tt0118571']
for i in actors['knownForTitles'].tolist():
    allTitles=allTitles+i.split(',')

uniqTitles = list(set(allTitles))
len(uniqTitles)
# Out:
# 362

# %% [markdown]
# # Scrape Related Fuctions

# %%
from bs4 import BeautifulSoup
from selenium import webdriver 
from selenium.webdriver.chrome.options import Options
import re 
import urllib
import time

# %%
#create a webdriver object and set options for headless browsing
options = Options()
options.headless = True
driver = webdriver.Chrome('./chromedriver',options=options)
#driver = webdriver.Chrome("/usr/local/bin/chromedriver",options=options)

# %%
#uses webdriver object to execute javascript code and get dynamically loaded webcontent
def get_js_soup(url,driver):
    driver.get(url)
    res_html = driver.execute_script('return document.body.innerHTML')
    soup = BeautifulSoup(res_html,'html.parser') #beautiful soup object to be used for parsing html content
    return soup

#tidies extracted text 
def process_bio(bio):
    bio = bio.encode('ascii',errors='ignore').decode('utf-8')       #removes non-ascii characters
    bio = re.sub('\s+',' ',bio)       #repalces repeated whitespace characters with single space
    return bio

''' More tidying
Sometimes the text extracted HTML webpage may contain javascript code and some style elements. 
This function removes script and style tags from HTML so that extracted text does not contain them.
'''
def remove_script(soup):
    for script in soup(["script", "style"]):
        script.decompose()
    return soup


#Checks if bio_url is a valid faculty homepage
def is_valid_homepage(bio_url,dir_url):
    if bio_url.endswith('.pdf'): #we're not parsing pdfs
        return False
    try:
        #sometimes the homepage url points to the same page as the faculty profile page
        #which should be treated differently from an actual homepage
        ret_url = urllib.request.urlopen(bio_url).geturl() 
    except:
        return False       #unable to access bio_url
    urls = [re.sub('((https?://)|(www.))','',url) for url in [ret_url,dir_url]] #removes url scheme (https,http or www) 
    return not(urls[0]== urls[1])

def scrape_movie_page(fac_url,driver):
    soup = get_js_soup(fac_url,driver)
    homepage_found = False
    bio_url = fac_url
    #profile_sec = soup.find('section',class_='main-content')
    profile_sec = soup.find('section',class_='article listo')
    if profile_sec == None:
        bio = ''
        print("Skipping bio : ",bio_url)
    else:
        bio = process_bio(profile_sec.get_text(separator=' '))
    #print("bio is ",bio_url)
    return bio_url,bio

# %%
def write_lst(lst,file_):
    lst = lst.replace(' Plot Showing all 0 items Jump to: ','')
    lst = lst.replace(' Plot Showing all 1 items Jump to: Summaries (1) ','')
    lst = lst.replace(' Plot Showing all 2 items Jump to: Summaries (2) ','')
    lst = lst.replace(' Plot Showing all 3 items Jump to: Summaries (3) ','')
    lst = lst.replace(' Plot Showing all ','').replace(' items Jump to: Summaries (','')
    lst = lst.replace(') Synopsis (','').replace(' Synopsis','').replace(' Summaries','')
    #lst = lst[6:]
    lst = lst.replace('Edit ','')
    #lst = lst.replace(' Summaries ','\n\nSummaries\n')
    #lst = lst.replace(' Synopsis ','\n\nSynopsis\n')

    with open(file_,'w') as f:
        f.write(lst)

# %% [markdown]
# # Scrape Movie plot summary and store in "movieFile" dir

# %%
#Scrape homepages of all urls
tot_urls = len(uniqTitles)
for i,l in enumerate(uniqTitles):
    link="https://www.imdb.com/title/"+l+"/plotsummary"
    print ('-'*20,'Scraping movie url {}/{}'.format(i+1,tot_urls),'-'*20)
    print(link)
    bio_urls, bios = [],[]
    bio_url,bio = scrape_movie_page(link,driver)
    if bio.strip()!= '' and bio_url.strip()!='':  
        bio_file = 'movieFile/'+l+'.txt'
        write_lst(bio,bio_file)
driver.close()
# Out:
# -------------------- Scraping movie url 1/362 --------------------
# https://www.imdb.com/title/tt0100405/plotsummary
# -------------------- Scraping movie url 2/362 --------------------
# https://www.imdb.com/title/tt0095169/plotsummary
# -------------------- Scraping movie url 3/362 --------------------
# https://www.imdb.com/title/tt0134119/plotsummary
# -------------------- Scraping movie url 4/362 --------------------
# https://www.imdb.com/title/tt0096018/plotsummary
# -------------------- Scraping movie url 5/362 --------------------
# https://www.imdb.com/title/tt0250797/plotsummary
# -------------------- Scraping movie url 6/362 --------------------
# https://www.imdb.com/title/tt0087538/plotsummary
# -------------------- Scraping movie url 7/362 --------------------
# https://www.imdb.com/title/tt1024648/plotsummary
# -------------------- Scraping movie url 8/362 --------------------
# https://www.imdb.com/title/tt0091790/plotsummary
# -------------------- Scraping movie url 9/362 --------------------
# https://www.imdb.com/title/tt0162346/plotsummary
# -------------------- Scraping movie url 10/362 --------------------
# https://www.imdb.com/title/tt0935075/plotsummary
# -------------------- Scraping movie url 11/362 --------------------
# https://www.imdb.com/title/tt0088128/plotsummary
# -------------------- Scraping movie url 12/362 --------------------
# https://www.imdb.com/title/tt0091557/plotsummary
# -------------------- Scraping movie url 13/362 --------------------
# https://www.imdb.com/title/tt0328589/plotsummary
# -------------------- Scraping movie url 14/362 --------------------
# https://www.imdb.com/title/tt0379786/plotsummary
# -------------------- Scraping movie url 15/362 --------------------
# https://www.imdb.com/title/tt0426592/plotsummary
# -------------------- Scraping movie url 16/362 --------------------
# https://www.imdb.com/title/tt0099653/plotsummary
# -------------------- Scraping movie url 17/362 --------------------
# https://www.imdb.com/title/tt0117509/plotsummary
# -------------------- Scraping movie url 18/362 --------------------
# https://www.imdb.com/title/tt0119738/plotsummary
# -------------------- Scraping movie url 19/362 --------------------
# https://www.imdb.com/title/tt0430357/plotsummary
# -------------------- Scraping movie url 20/362 --------------------
# https://www.imdb.com/title/tt0452702/plotsummary
# -------------------- Scraping movie url 21/362 --------------------
# https://www.imdb.com/title/tt0401855/plotsummary
# -------------------- Scraping movie url 22/362 --------------------
# https://www.imdb.com/title/tt1735898/plotsummary
# -------------------- Scraping movie url 23/362 --------------------
# https://www.imdb.com/title/tt0276919/plotsummary
# -------------------- Scraping movie url 24/362 --------------------
# https://www.imdb.com/title/tt2267998/plotsummary
# -------------------- Scraping movie url 25/362 --------------------
# https://www.imdb.com/title/tt0120885/plotsummary
# -------------------- Scraping movie url 26/362 --------------------
# https://www.imdb.com/title/tt0116365/plotsummary
# -------------------- Scraping movie url 27/362 --------------------
# https://www.imdb.com/title/tt0473444/plotsummary
# -------------------- Scraping movie url 28/362 --------------------
# https://www.imdb.com/title/tt0110475/plotsummary
# -------------------- Scraping movie url 29/362 --------------------
# https://www.imdb.com/title/tt1796960/plotsummary
# -------------------- Scraping movie url 30/362 --------------------
# https://www.imdb.com/title/tt0380623/plotsummary
# -------------------- Scraping movie url 31/362 --------------------
# https://www.imdb.com/title/tt0395251/plotsummary
# -------------------- Scraping movie url 32/362 --------------------
# https://www.imdb.com/title/tt0105046/plotsummary
# -------------------- Scraping movie url 33/362 --------------------
# https://www.imdb.com/title/tt0095963/plotsummary
# -------------------- Scraping movie url 34/362 --------------------
# https://www.imdb.com/title/tt0116287/plotsummary
# -------------------- Scraping movie url 35/362 --------------------
# https://www.imdb.com/title/tt1540133/plotsummary
# -------------------- Scraping movie url 36/362 --------------------
# https://www.imdb.com/title/tt0094291/plotsummary
# -------------------- Scraping movie url 37/362 --------------------
# https://www.imdb.com/title/tt0295178/plotsummary
# -------------------- Scraping movie url 38/362 --------------------
# https://www.imdb.com/title/tt0160127/plotsummary
# -------------------- Scraping movie url 39/362 --------------------
# https://www.imdb.com/title/tt0101393/plotsummary
# -------------------- Scraping movie url 40/362 --------------------
# https://www.imdb.com/title/tt0105104/plotsummary
# -------------------- Scraping movie url 41/362 --------------------
# https://www.imdb.com/title/tt0098800/plotsummary
# -------------------- Scraping movie url 42/362 --------------------
# https://www.imdb.com/title/tt0108052/plotsummary
# -------------------- Scraping movie url 43/362 --------------------
# https://www.imdb.com/title/tt1193138/plotsummary
# -------------------- Scraping movie url 44/362 --------------------
# https://www.imdb.com/title/tt0108162/plotsummary
# -------------------- Scraping movie url 45/362 --------------------
# https://www.imdb.com/title/tt0369179/plotsummary
# -------------------- Scraping movie url 46/362 --------------------
# https://www.imdb.com/title/tt0356910/plotsummary
# -------------------- Scraping movie url 47/362 --------------------
# https://www.imdb.com/title/tt0106179/plotsummary
# -------------------- Scraping movie url 48/362 --------------------
# https://www.imdb.com/title/tt0212346/plotsummary
# -------------------- Scraping movie url 49/362 --------------------
# https://www.imdb.com/title/tt3460252/plotsummary
# -------------------- Scraping movie url 50/362 --------------------
# https://www.imdb.com/title/tt0098193/plotsummary
# -------------------- Scraping movie url 51/362 --------------------
# https://www.imdb.com/title/tt0115624/plotsummary
# -------------------- Scraping movie url 52/362 --------------------
# https://www.imdb.com/title/tt0988047/plotsummary
# -------------------- Scraping movie url 53/362 --------------------
# https://www.imdb.com/title/tt0110413/plotsummary
# -------------------- Scraping movie url 54/362 --------------------
# https://www.imdb.com/title/tt1915581/plotsummary
# -------------------- Scraping movie url 55/362 --------------------
# https://www.imdb.com/title/tt0113627/plotsummary
# -------------------- Scraping movie url 56/362 --------------------
# https://www.imdb.com/title/tt0092099/plotsummary
# -------------------- Scraping movie url 57/362 --------------------
# https://www.imdb.com/title/tt0092005/plotsummary
# -------------------- Scraping movie url 58/362 --------------------
# https://www.imdb.com/title/tt0107144/plotsummary
# -------------------- Scraping movie url 59/362 --------------------
# https://www.imdb.com/title/tt0112642/plotsummary
# -------------------- Scraping movie url 60/362 --------------------
# https://www.imdb.com/title/tt0112515/plotsummary
# -------------------- Scraping movie url 61/362 --------------------
# https://www.imdb.com/title/tt0159365/plotsummary
# -------------------- Scraping movie url 62/362 --------------------
# https://www.imdb.com/title/tt0320691/plotsummary
# -------------------- Scraping movie url 63/362 --------------------
# https://www.imdb.com/title/tt2126357/plotsummary
# -------------------- Scraping movie url 64/362 --------------------
# https://www.imdb.com/title/tt0120577/plotsummary
# -------------------- Scraping movie url 65/362 --------------------
# https://www.imdb.com/title/tt3442006/plotsummary
# -------------------- Scraping movie url 66/362 --------------------
# https://www.imdb.com/title/tt0387131/plotsummary
# -------------------- Scraping movie url 67/362 --------------------
# https://www.imdb.com/title/tt0434409/plotsummary
# -------------------- Scraping movie url 68/362 --------------------
# https://www.imdb.com/title/tt0243155/plotsummary
# -------------------- Scraping movie url 69/362 --------------------
# https://www.imdb.com/title/tt0114608/plotsummary
# -------------------- Scraping movie url 70/362 --------------------
# https://www.imdb.com/title/tt0150377/plotsummary
# -------------------- Scraping movie url 71/362 --------------------
# https://www.imdb.com/title/tt2763304/plotsummary
# -------------------- Scraping movie url 72/362 --------------------
# https://www.imdb.com/title/tt0111438/plotsummary
# -------------------- Scraping movie url 73/362 --------------------
# https://www.imdb.com/title/tt0083929/plotsummary
# -------------------- Scraping movie url 74/362 --------------------
# https://www.imdb.com/title/tt0132347/plotsummary
# -------------------- Scraping movie url 75/362 --------------------
# https://www.imdb.com/title/tt0119654/plotsummary
# -------------------- Scraping movie url 76/362 --------------------
# https://www.imdb.com/title/tt0947798/plotsummary
# -------------------- Scraping movie url 77/362 --------------------
# https://www.imdb.com/title/tt2935510/plotsummary
# -------------------- Scraping movie url 78/362 --------------------
# https://www.imdb.com/title/tt0189142/plotsummary
# -------------------- Scraping movie url 79/362 --------------------
# https://www.imdb.com/title/tt0119141/plotsummary
# -------------------- Scraping movie url 80/362 --------------------
# https://www.imdb.com/title/tt0158622/plotsummary
# -------------------- Scraping movie url 81/362 --------------------
# https://www.imdb.com/title/tt0102803/plotsummary
# -------------------- Scraping movie url 82/362 --------------------
# https://www.imdb.com/title/tt1375666/plotsummary
# -------------------- Scraping movie url 83/362 --------------------
# https://www.imdb.com/title/tt0083866/plotsummary
# -------------------- Scraping movie url 84/362 --------------------
# https://www.imdb.com/title/tt0352277/plotsummary
# -------------------- Scraping movie url 85/362 --------------------
# https://www.imdb.com/title/tt0252076/plotsummary
# -------------------- Scraping movie url 86/362 --------------------
# https://www.imdb.com/title/tt0089908/plotsummary
# -------------------- Scraping movie url 87/362 --------------------
# https://www.imdb.com/title/tt0080453/plotsummary
# -------------------- Scraping movie url 88/362 --------------------
# https://www.imdb.com/title/tt1220634/plotsummary
# -------------------- Scraping movie url 89/362 --------------------
# https://www.imdb.com/title/tt0094761/plotsummary
# -------------------- Scraping movie url 90/362 --------------------
# https://www.imdb.com/title/tt0119217/plotsummary
# -------------------- Scraping movie url 91/362 --------------------
# https://www.imdb.com/title/tt0338526/plotsummary
# -------------------- Scraping movie url 92/362 --------------------
# https://www.imdb.com/title/tt0134084/plotsummary
# -------------------- Scraping movie url 93/362 --------------------
# https://www.imdb.com/title/tt0395584/plotsummary
# -------------------- Scraping movie url 94/362 --------------------
# https://www.imdb.com/title/tt0118655/plotsummary
# -------------------- Scraping movie url 95/362 --------------------
# https://www.imdb.com/title/tt0089218/plotsummary
# -------------------- Scraping movie url 96/362 --------------------
# https://www.imdb.com/title/tt0117060/plotsummary
# -------------------- Scraping movie url 97/362 --------------------
# https://www.imdb.com/title/tt0158552/plotsummary
# -------------------- Scraping movie url 98/362 --------------------
# https://www.imdb.com/title/tt0107120/plotsummary
# -------------------- Scraping movie url 99/362 --------------------
# https://www.imdb.com/title/tt0435705/plotsummary
# -------------------- Scraping movie url 100/362 --------------------
# https://www.imdb.com/title/tt0106057/plotsummary
# -------------------- Scraping movie url 101/362 --------------------
# https://www.imdb.com/title/tt0101775/plotsummary
# -------------------- Scraping movie url 102/362 --------------------
# https://www.imdb.com/title/tt0116629/plotsummary
# -------------------- Scraping movie url 103/362 --------------------
# https://www.imdb.com/title/tt0181875/plotsummary
# -------------------- Scraping movie url 104/362 --------------------
# https://www.imdb.com/title/tt0455967/plotsummary
# -------------------- Scraping movie url 105/362 --------------------
# https://www.imdb.com/title/tt0087884/plotsummary
# -------------------- Scraping movie url 106/362 --------------------
# https://www.imdb.com/title/tt0372784/plotsummary
# -------------------- Scraping movie url 107/362 --------------------
# https://www.imdb.com/title/tt0120347/plotsummary
# -------------------- Scraping movie url 108/362 --------------------
# https://www.imdb.com/title/tt0964517/plotsummary
# -------------------- Scraping movie url 109/362 --------------------
# https://www.imdb.com/title/tt0811138/plotsummary
# -------------------- Scraping movie url 110/362 --------------------
# https://www.imdb.com/title/tt2120120/plotsummary
# -------------------- Scraping movie url 111/362 --------------------
# https://www.imdb.com/title/tt0098635/plotsummary
# -------------------- Scraping movie url 112/362 --------------------
# https://www.imdb.com/title/tt0119468/plotsummary
# -------------------- Scraping movie url 113/362 --------------------
# https://www.imdb.com/title/tt0108872/plotsummary
# -------------------- Scraping movie url 114/362 --------------------
# https://www.imdb.com/title/tt0119271/plotsummary
# -------------------- Scraping movie url 115/362 --------------------
# https://www.imdb.com/title/tt0337851/plotsummary
# -------------------- Scraping movie url 116/362 --------------------
# https://www.imdb.com/title/tt0275847/plotsummary
# -------------------- Scraping movie url 117/362 --------------------
# https://www.imdb.com/title/tt0119094/plotsummary
# -------------------- Scraping movie url 118/362 --------------------
# https://www.imdb.com/title/tt0119173/plotsummary
# -------------------- Scraping movie url 119/362 --------------------
# https://www.imdb.com/title/tt5610554/plotsummary
# -------------------- Scraping movie url 120/362 --------------------
# https://www.imdb.com/title/tt0108778/plotsummary
# -------------------- Scraping movie url 121/362 --------------------
# https://www.imdb.com/title/tt0128853/plotsummary
# -------------------- Scraping movie url 122/362 --------------------
# https://www.imdb.com/title/tt0407887/plotsummary
# -------------------- Scraping movie url 123/362 --------------------
# https://www.imdb.com/title/tt0111503/plotsummary
# -------------------- Scraping movie url 124/362 --------------------
# https://www.imdb.com/title/tt0482606/plotsummary
# -------------------- Scraping movie url 125/362 --------------------
# https://www.imdb.com/title/tt0092240/plotsummary
# -------------------- Scraping movie url 126/362 --------------------
# https://www.imdb.com/title/tt0103491/plotsummary
# -------------------- Scraping movie url 127/362 --------------------
# https://www.imdb.com/title/tt0105323/plotsummary
# -------------------- Scraping movie url 128/362 --------------------
# https://www.imdb.com/title/tt0277371/plotsummary
# -------------------- Scraping movie url 129/362 --------------------
# https://www.imdb.com/title/tt0075314/plotsummary
# -------------------- Scraping movie url 130/362 --------------------
# https://www.imdb.com/title/tt0106677/plotsummary
# -------------------- Scraping movie url 131/362 --------------------
# https://www.imdb.com/title/tt0114746/plotsummary
# -------------------- Scraping movie url 132/362 --------------------
# https://www.imdb.com/title/tt0110367/plotsummary
# -------------------- Scraping movie url 133/362 --------------------
# https://www.imdb.com/title/tt0327643/plotsummary
# -------------------- Scraping movie url 134/362 --------------------
# https://www.imdb.com/title/tt0114814/plotsummary
# -------------------- Scraping movie url 135/362 --------------------
# https://www.imdb.com/title/tt0115285/plotsummary
# -------------------- Scraping movie url 136/362 --------------------
# https://www.imdb.com/title/tt0093058/plotsummary
# -------------------- Scraping movie url 137/362 --------------------
# https://www.imdb.com/title/tt0274558/plotsummary
# -------------------- Scraping movie url 138/362 --------------------
# https://www.imdb.com/title/tt1615065/plotsummary
# -------------------- Scraping movie url 139/362 --------------------
# https://www.imdb.com/title/tt0230030/plotsummary
# -------------------- Scraping movie url 140/362 --------------------
# https://www.imdb.com/title/tt0480249/plotsummary
# -------------------- Scraping movie url 141/362 --------------------
# https://www.imdb.com/title/tt0821640/plotsummary
# -------------------- Scraping movie url 142/362 --------------------
# https://www.imdb.com/title/tt0093779/plotsummary
# -------------------- Scraping movie url 143/362 --------------------
# https://www.imdb.com/title/tt0111257/plotsummary
# -------------------- Scraping movie url 144/362 --------------------
# https://www.imdb.com/title/tt2209418/plotsummary
# -------------------- Scraping movie url 145/362 --------------------
# https://www.imdb.com/title/tt0098936/plotsummary
# -------------------- Scraping movie url 146/362 --------------------
# https://www.imdb.com/title/tt0180093/plotsummary
# -------------------- Scraping movie url 147/362 --------------------
# https://www.imdb.com/title/tt0810788/plotsummary
# -------------------- Scraping movie url 148/362 --------------------
# https://www.imdb.com/title/tt0124298/plotsummary
# -------------------- Scraping movie url 149/362 --------------------
# https://www.imdb.com/title/tt0131857/plotsummary
# -------------------- Scraping movie url 150/362 --------------------
# https://www.imdb.com/title/tt0338013/plotsummary
# -------------------- Scraping movie url 151/362 --------------------
# https://www.imdb.com/title/tt0124198/plotsummary
# -------------------- Scraping movie url 152/362 --------------------
# https://www.imdb.com/title/tt0114660/plotsummary
# -------------------- Scraping movie url 153/362 --------------------
# https://www.imdb.com/title/tt0115759/plotsummary
# -------------------- Scraping movie url 154/362 --------------------
# https://www.imdb.com/title/tt0470705/plotsummary
# -------------------- Scraping movie url 155/362 --------------------
# https://www.imdb.com/title/tt0340855/plotsummary
# -------------------- Scraping movie url 156/362 --------------------
# https://www.imdb.com/title/tt0096697/plotsummary
# -------------------- Scraping movie url 157/362 --------------------
# https://www.imdb.com/title/tt0409572/plotsummary
# -------------------- Scraping movie url 158/362 --------------------
# https://www.imdb.com/title/tt0210365/plotsummary
# -------------------- Scraping movie url 159/362 --------------------
# https://www.imdb.com/title/tt0113819/plotsummary
# -------------------- Scraping movie url 160/362 --------------------
# https://www.imdb.com/title/tt0125377/plotsummary
# -------------------- Scraping movie url 161/362 --------------------
# https://www.imdb.com/title/tt0102798/plotsummary
# -------------------- Scraping movie url 162/362 --------------------
# https://www.imdb.com/title/tt0114781/plotsummary
# -------------------- Scraping movie url 163/362 --------------------
# https://www.imdb.com/title/tt0207919/plotsummary
# -------------------- Scraping movie url 164/362 --------------------
# https://www.imdb.com/title/tt0367594/plotsummary
# -------------------- Scraping movie url 165/362 --------------------
# https://www.imdb.com/title/tt0430922/plotsummary
# -------------------- Scraping movie url 166/362 --------------------
# https://www.imdb.com/title/tt0105690/plotsummary
# -------------------- Scraping movie url 167/362 --------------------
# https://www.imdb.com/title/tt0227538/plotsummary
# -------------------- Scraping movie url 168/362 --------------------
# https://www.imdb.com/title/tt0113277/plotsummary
# -------------------- Scraping movie url 169/362 --------------------
# https://www.imdb.com/title/tt0266697/plotsummary
# -------------------- Scraping movie url 170/362 --------------------
# https://www.imdb.com/title/tt0118749/plotsummary
# -------------------- Scraping movie url 171/362 --------------------
# https://www.imdb.com/title/tt0119086/plotsummary
# -------------------- Scraping movie url 172/362 --------------------
# https://www.imdb.com/title/tt0118688/plotsummary
# -------------------- Scraping movie url 173/362 --------------------
# https://www.imdb.com/title/tt0195685/plotsummary
# -------------------- Scraping movie url 174/362 --------------------
# https://www.imdb.com/title/tt1723121/plotsummary
# -------------------- Scraping movie url 175/362 --------------------
# https://www.imdb.com/title/tt0096874/plotsummary
# -------------------- Scraping movie url 176/362 --------------------
# https://www.imdb.com/title/tt0167260/plotsummary
# -------------------- Scraping movie url 177/362 --------------------
# https://www.imdb.com/title/tt0120008/plotsummary
# -------------------- Scraping movie url 178/362 --------------------
# https://www.imdb.com/title/tt0408236/plotsummary
# -------------------- Scraping movie url 179/362 --------------------
# https://www.imdb.com/title/tt0133093/plotsummary
# -------------------- Scraping movie url 180/362 --------------------
# https://www.imdb.com/title/tt0359013/plotsummary
# -------------------- Scraping movie url 181/362 --------------------
# https://www.imdb.com/title/tt0172495/plotsummary
# -------------------- Scraping movie url 182/362 --------------------
# https://www.imdb.com/title/tt1707386/plotsummary
# -------------------- Scraping movie url 183/362 --------------------
# https://www.imdb.com/title/tt1220198/plotsummary
# -------------------- Scraping movie url 184/362 --------------------
# https://www.imdb.com/title/tt0120804/plotsummary
# -------------------- Scraping movie url 185/362 --------------------
# https://www.imdb.com/title/tt0348150/plotsummary
# -------------------- Scraping movie url 186/362 --------------------
# https://www.imdb.com/title/tt0116695/plotsummary
# -------------------- Scraping movie url 187/362 --------------------
# https://www.imdb.com/title/tt0088944/plotsummary
# -------------------- Scraping movie url 188/362 --------------------
# https://www.imdb.com/title/tt0993846/plotsummary
# -------------------- Scraping movie url 189/362 --------------------
# https://www.imdb.com/title/tt0119116/plotsummary
# -------------------- Scraping movie url 190/362 --------------------
# https://www.imdb.com/title/tt0091042/plotsummary
# -------------------- Scraping movie url 191/362 --------------------
# https://www.imdb.com/title/tt0120591/plotsummary
# -------------------- Scraping movie url 192/362 --------------------
# https://www.imdb.com/title/tt2452254/plotsummary
# -------------------- Scraping movie url 193/362 --------------------
# https://www.imdb.com/title/tt0118884/plotsummary
# -------------------- Scraping movie url 194/362 --------------------
# https://www.imdb.com/title/tt0375679/plotsummary
# -------------------- Scraping movie url 195/362 --------------------
# https://www.imdb.com/title/tt0129387/plotsummary
# -------------------- Scraping movie url 196/362 --------------------
# https://www.imdb.com/title/tt0112697/plotsummary
# -------------------- Scraping movie url 197/362 --------------------
# https://www.imdb.com/title/tt0367089/plotsummary
# -------------------- Scraping movie url 198/362 --------------------
# https://www.imdb.com/title/tt0086567/plotsummary
# -------------------- Scraping movie url 199/362 --------------------
# https://www.imdb.com/title/tt0259711/plotsummary
# -------------------- Scraping movie url 200/362 --------------------
# https://www.imdb.com/title/tt0268978/plotsummary
# -------------------- Scraping movie url 201/362 --------------------
# https://www.imdb.com/title/tt0116209/plotsummary
# -------------------- Scraping movie url 202/362 --------------------
# https://www.imdb.com/title/tt0433383/plotsummary
# -------------------- Scraping movie url 203/362 --------------------
# https://www.imdb.com/title/tt0120032/plotsummary
# -------------------- Scraping movie url 204/362 --------------------
# https://www.imdb.com/title/tt0120338/plotsummary
# -------------------- Scraping movie url 205/362 --------------------
# https://www.imdb.com/title/tt0410975/plotsummary
# -------------------- Scraping movie url 206/362 --------------------
# https://www.imdb.com/title/tt0097493/plotsummary
# -------------------- Scraping movie url 207/362 --------------------
# https://www.imdb.com/title/tt0139134/plotsummary
# -------------------- Scraping movie url 208/362 --------------------
# https://www.imdb.com/title/tt0279113/plotsummary
# -------------------- Scraping movie url 209/362 --------------------
# https://www.imdb.com/title/tt0120611/plotsummary
# -------------------- Scraping movie url 210/362 --------------------
# https://www.imdb.com/title/tt0102494/plotsummary
# -------------------- Scraping movie url 211/362 --------------------
# https://www.imdb.com/title/tt0088847/plotsummary
# -------------------- Scraping movie url 212/362 --------------------
# https://www.imdb.com/title/tt0098258/plotsummary
# -------------------- Scraping movie url 213/362 --------------------
# https://www.imdb.com/title/tt0343660/plotsummary
# -------------------- Scraping movie url 214/362 --------------------
# https://www.imdb.com/title/tt0267913/plotsummary
# -------------------- Scraping movie url 215/362 --------------------
# https://www.imdb.com/title/tt0162222/plotsummary
# -------------------- Scraping movie url 216/362 --------------------
# https://www.imdb.com/title/tt0086827/plotsummary
# -------------------- Scraping movie url 217/362 --------------------
# https://www.imdb.com/title/tt0110912/plotsummary
# -------------------- Scraping movie url 218/362 --------------------
# https://www.imdb.com/title/tt0315327/plotsummary
# -------------------- Scraping movie url 219/362 --------------------
# https://www.imdb.com/title/tt0119229/plotsummary
# -------------------- Scraping movie url 220/362 --------------------
# https://www.imdb.com/title/tt0118789/plotsummary
# -------------------- Scraping movie url 221/362 --------------------
# https://www.imdb.com/title/tt0412175/plotsummary
# -------------------- Scraping movie url 222/362 --------------------
# https://www.imdb.com/title/tt0120755/plotsummary
# -------------------- Scraping movie url 223/362 --------------------
# https://www.imdb.com/title/tt0078111/plotsummary
# -------------------- Scraping movie url 224/362 --------------------
# https://www.imdb.com/title/tt0913354/plotsummary
# -------------------- Scraping movie url 225/362 --------------------
# https://www.imdb.com/title/tt1250777/plotsummary
# -------------------- Scraping movie url 226/362 --------------------
# https://www.imdb.com/title/tt0119008/plotsummary
# -------------------- Scraping movie url 227/362 --------------------
# https://www.imdb.com/title/tt1392190/plotsummary
# -------------------- Scraping movie url 228/362 --------------------
# https://www.imdb.com/title/tt0182587/plotsummary
# -------------------- Scraping movie url 229/362 --------------------
# https://www.imdb.com/title/tt0105112/plotsummary
# -------------------- Scraping movie url 230/362 --------------------
# https://www.imdb.com/title/tt1065073/plotsummary
# -------------------- Scraping movie url 231/362 --------------------
# https://www.imdb.com/title/tt0378194/plotsummary
# -------------------- Scraping movie url 232/362 --------------------
# https://www.imdb.com/title/tt0151738/plotsummary
# -------------------- Scraping movie url 233/362 --------------------
# https://www.imdb.com/title/tt0107211/plotsummary
# -------------------- Scraping movie url 234/362 --------------------
# https://www.imdb.com/title/tt0364343/plotsummary
# -------------------- Scraping movie url 235/362 --------------------
# https://www.imdb.com/title/tt0120679/plotsummary
# -------------------- Scraping movie url 236/362 --------------------
# https://www.imdb.com/title/tt0119822/plotsummary
# -------------------- Scraping movie url 237/362 --------------------
# https://www.imdb.com/title/tt1637725/plotsummary
# -------------------- Scraping movie url 238/362 --------------------
# https://www.imdb.com/title/tt0106220/plotsummary
# -------------------- Scraping movie url 239/362 --------------------
# https://www.imdb.com/title/tt0187393/plotsummary
# -------------------- Scraping movie url 240/362 --------------------
# https://www.imdb.com/title/tt0117951/plotsummary
# -------------------- Scraping movie url 241/362 --------------------
# https://www.imdb.com/title/tt0251160/plotsummary
# -------------------- Scraping movie url 242/362 --------------------
# https://www.imdb.com/title/tt0120828/plotsummary
# -------------------- Scraping movie url 243/362 --------------------
# https://www.imdb.com/title/tt0234215/plotsummary
# -------------------- Scraping movie url 244/362 --------------------
# https://www.imdb.com/title/tt0134898/plotsummary
# -------------------- Scraping movie url 245/362 --------------------
# https://www.imdb.com/title/tt0116367/plotsummary
# -------------------- Scraping movie url 246/362 --------------------
# https://www.imdb.com/title/tt0397535/plotsummary
# -------------------- Scraping movie url 247/362 --------------------
# https://www.imdb.com/title/tt1124035/plotsummary
# -------------------- Scraping movie url 248/362 --------------------
# https://www.imdb.com/title/tt2278388/plotsummary
# -------------------- Scraping movie url 249/362 --------------------
# https://www.imdb.com/title/tt2294189/plotsummary
# -------------------- Scraping movie url 250/362 --------------------
# https://www.imdb.com/title/tt0283084/plotsummary
# -------------------- Scraping movie url 251/362 --------------------
# https://www.imdb.com/title/tt0119925/plotsummary
# -------------------- Scraping movie url 252/362 --------------------
# https://www.imdb.com/title/tt0203009/plotsummary
# -------------------- Scraping movie url 253/362 --------------------
# https://www.imdb.com/title/tt0476964/plotsummary
# -------------------- Scraping movie url 254/362 --------------------
# https://www.imdb.com/title/tt0119695/plotsummary
# -------------------- Scraping movie url 255/362 --------------------
# https://www.imdb.com/title/tt0107076/plotsummary
# -------------------- Scraping movie url 256/362 --------------------
# https://www.imdb.com/title/tt0108333/plotsummary
# -------------------- Scraping movie url 257/362 --------------------
# https://www.imdb.com/title/tt0306047/plotsummary
# -------------------- Scraping movie url 258/362 --------------------
# https://www.imdb.com/title/tt0376541/plotsummary
# -------------------- Scraping movie url 259/362 --------------------
# https://www.imdb.com/title/tt0103484/plotsummary
# -------------------- Scraping movie url 260/362 --------------------
# https://www.imdb.com/title/tt0486583/plotsummary
# -------------------- Scraping movie url 261/362 --------------------
# https://www.imdb.com/title/tt2096673/plotsummary
# -------------------- Scraping movie url 262/362 --------------------
# https://www.imdb.com/title/tt0840361/plotsummary
# -------------------- Scraping movie url 263/362 --------------------
# https://www.imdb.com/title/tt0100935/plotsummary
# -------------------- Scraping movie url 264/362 --------------------
# https://www.imdb.com/title/tt0395169/plotsummary
# -------------------- Scraping movie url 265/362 --------------------
# https://www.imdb.com/title/tt0120053/plotsummary
# -------------------- Scraping movie url 266/362 --------------------
# https://www.imdb.com/title/tt0108399/plotsummary
# -------------------- Scraping movie url 267/362 --------------------
# https://www.imdb.com/title/tt0346156/plotsummary
# -------------------- Scraping movie url 268/362 --------------------
# https://www.imdb.com/title/tt1839481/plotsummary
# -------------------- Scraping movie url 269/362 --------------------
# https://www.imdb.com/title/tt0101640/plotsummary
# -------------------- Scraping movie url 270/362 --------------------
# https://www.imdb.com/title/tt0305357/plotsummary
# -------------------- Scraping movie url 271/362 --------------------
# https://www.imdb.com/title/tt0280707/plotsummary
# -------------------- Scraping movie url 272/362 --------------------
# https://www.imdb.com/title/tt0112851/plotsummary
# -------------------- Scraping movie url 273/362 --------------------
# https://www.imdb.com/title/tt0145660/plotsummary
# -------------------- Scraping movie url 274/362 --------------------
# https://www.imdb.com/title/tt0086066/plotsummary
# -------------------- Scraping movie url 275/362 --------------------
# https://www.imdb.com/title/tt0120082/plotsummary
# -------------------- Scraping movie url 276/362 --------------------
# https://www.imdb.com/title/tt0115369/plotsummary
# -------------------- Scraping movie url 277/362 --------------------
# https://www.imdb.com/title/tt0089469/plotsummary
# -------------------- Scraping movie url 278/362 --------------------
# https://www.imdb.com/title/tt0283832/plotsummary
# -------------------- Scraping movie url 279/362 --------------------
# https://www.imdb.com/title/tt0381681/plotsummary
# -------------------- Scraping movie url 280/362 --------------------
# https://www.imdb.com/title/tt0113010/plotsummary
# -------------------- Scraping movie url 281/362 --------------------
# https://www.imdb.com/title/tt0112471/plotsummary
# -------------------- Scraping movie url 282/362 --------------------
# https://www.imdb.com/title/tt0449088/plotsummary
# -------------------- Scraping movie url 283/362 --------------------
# https://www.imdb.com/title/tt5503686/plotsummary
# -------------------- Scraping movie url 284/362 --------------------
# https://www.imdb.com/title/tt0120632/plotsummary
# -------------------- Scraping movie url 285/362 --------------------
# https://www.imdb.com/title/tt0450385/plotsummary
# -------------------- Scraping movie url 286/362 --------------------
# https://www.imdb.com/title/tt0169547/plotsummary
# -------------------- Scraping movie url 287/362 --------------------
# https://www.imdb.com/title/tt0105793/plotsummary
# -------------------- Scraping movie url 288/362 --------------------
# https://www.imdb.com/title/tt0111400/plotsummary
# -------------------- Scraping movie url 289/362 --------------------
# https://www.imdb.com/title/tt1219827/plotsummary
# -------------------- Scraping movie url 290/362 --------------------
# https://www.imdb.com/title/tt0299658/plotsummary
# -------------------- Scraping movie url 291/362 --------------------
# https://www.imdb.com/title/tt0099487/plotsummary
# -------------------- Scraping movie url 292/362 --------------------
# https://www.imdb.com/title/tt0866437/plotsummary
# -------------------- Scraping movie url 293/362 --------------------
# https://www.imdb.com/title/tt1800241/plotsummary
# -------------------- Scraping movie url 294/362 --------------------
# https://www.imdb.com/title/tt0315983/plotsummary
# -------------------- Scraping movie url 295/362 --------------------
# https://www.imdb.com/title/tt0086143/plotsummary
# -------------------- Scraping movie url 296/362 --------------------
# https://www.imdb.com/title/tt0181852/plotsummary
# -------------------- Scraping movie url 297/362 --------------------
# https://www.imdb.com/title/tt0118571/plotsummary
# -------------------- Scraping movie url 298/362 --------------------
# https://www.imdb.com/title/tt1041829/plotsummary
# -------------------- Scraping movie url 299/362 --------------------
# https://www.imdb.com/title/tt1984153/plotsummary
# -------------------- Scraping movie url 300/362 --------------------
# https://www.imdb.com/title/tt0274298/plotsummary
# -------------------- Scraping movie url 301/362 --------------------
# https://www.imdb.com/title/tt0325710/plotsummary
# -------------------- Scraping movie url 302/362 --------------------
# https://www.imdb.com/title/tt0139654/plotsummary
# -------------------- Scraping movie url 303/362 --------------------
# https://www.imdb.com/title/tt0120631/plotsummary
# -------------------- Scraping movie url 304/362 --------------------
# https://www.imdb.com/title/tt0120891/plotsummary
# -------------------- Scraping movie url 305/362 --------------------
# https://www.imdb.com/title/tt0102685/plotsummary
# -------------------- Scraping movie url 306/362 --------------------
# https://www.imdb.com/title/tt0241303/plotsummary
# -------------------- Scraping movie url 307/362 --------------------
# https://www.imdb.com/title/tt0377092/plotsummary
# -------------------- Scraping movie url 308/362 --------------------
# https://www.imdb.com/title/tt0120890/plotsummary
# -------------------- Scraping movie url 309/362 --------------------
# https://www.imdb.com/title/tt0790636/plotsummary
# -------------------- Scraping movie url 310/362 --------------------
# https://www.imdb.com/title/tt0080116/plotsummary
# -------------------- Scraping movie url 311/362 --------------------
# https://www.imdb.com/title/tt1650554/plotsummary
# -------------------- Scraping movie url 312/362 --------------------
# https://www.imdb.com/title/tt1007028/plotsummary
# -------------------- Scraping movie url 313/362 --------------------
# https://www.imdb.com/title/tt0105236/plotsummary
# -------------------- Scraping movie url 314/362 --------------------
# https://www.imdb.com/title/tt1210166/plotsummary
# -------------------- Scraping movie url 315/362 --------------------
# https://www.imdb.com/title/tt0120737/plotsummary
# -------------------- Scraping movie url 316/362 --------------------
# https://www.imdb.com/title/tt0167261/plotsummary
# -------------------- Scraping movie url 317/362 --------------------
# https://www.imdb.com/title/tt0387564/plotsummary
# -------------------- Scraping movie url 318/362 --------------------
# https://www.imdb.com/title/tt1454468/plotsummary
# -------------------- Scraping movie url 319/362 --------------------
# https://www.imdb.com/title/tt0120586/plotsummary
# -------------------- Scraping movie url 320/362 --------------------
# https://www.imdb.com/title/tt1726669/plotsummary
# -------------------- Scraping movie url 321/362 --------------------
# https://www.imdb.com/title/tt0115683/plotsummary
# -------------------- Scraping movie url 322/362 --------------------
# https://www.imdb.com/title/tt0462200/plotsummary
# -------------------- Scraping movie url 323/362 --------------------
# https://www.imdb.com/title/tt0325980/plotsummary
# -------------------- Scraping movie url 324/362 --------------------
# https://www.imdb.com/title/tt0137523/plotsummary
# -------------------- Scraping movie url 325/362 --------------------
# https://www.imdb.com/title/tt1504320/plotsummary
# -------------------- Scraping movie url 326/362 --------------------
# https://www.imdb.com/title/tt0468569/plotsummary
# -------------------- Scraping movie url 327/362 --------------------
# https://www.imdb.com/title/tt0120512/plotsummary
# -------------------- Scraping movie url 328/362 --------------------
# https://www.imdb.com/title/tt0146882/plotsummary
# -------------------- Scraping movie url 329/362 --------------------
# https://www.imdb.com/title/tt0099329/plotsummary
# -------------------- Scraping movie url 330/362 --------------------
# https://www.imdb.com/title/tt0092513/plotsummary
# -------------------- Scraping movie url 331/362 --------------------
# https://www.imdb.com/title/tt0087363/plotsummary
# -------------------- Scraping movie url 332/362 --------------------
# https://www.imdb.com/title/tt0805570/plotsummary
# -------------------- Scraping movie url 333/362 --------------------
# https://www.imdb.com/title/tt0455590/plotsummary
# -------------------- Scraping movie url 334/362 --------------------
# https://www.imdb.com/title/tt0107977/plotsummary
# -------------------- Scraping movie url 335/362 --------------------
# https://www.imdb.com/title/tt0209069/plotsummary
# -------------------- Scraping movie url 336/362 --------------------
# https://www.imdb.com/title/tt0113947/plotsummary
# -------------------- Scraping movie url 337/362 --------------------
# https://www.imdb.com/title/tt0120780/plotsummary
# -------------------- Scraping movie url 338/362 --------------------
# https://www.imdb.com/title/tt0088763/plotsummary
# -------------------- Scraping movie url 339/362 --------------------
# https://www.imdb.com/title/tt0442632/plotsummary
# -------------------- Scraping movie url 340/362 --------------------
# https://www.imdb.com/title/tt0117998/plotsummary
# -------------------- Scraping movie url 341/362 --------------------
# https://www.imdb.com/title/tt0465538/plotsummary
# -------------------- Scraping movie url 342/362 --------------------
# https://www.imdb.com/title/tt1201607/plotsummary
# -------------------- Scraping movie url 343/362 --------------------
# https://www.imdb.com/title/tt0117500/plotsummary
# -------------------- Scraping movie url 344/362 --------------------
# https://www.imdb.com/title/tt0119488/plotsummary
# -------------------- Scraping movie url 345/362 --------------------
# https://www.imdb.com/title/tt0108160/plotsummary
# -------------------- Scraping movie url 346/362 --------------------
# https://www.imdb.com/title/tt0115685/plotsummary
# -------------------- Scraping movie url 347/362 --------------------
# https://www.imdb.com/title/tt0106400/plotsummary
# -------------------- Scraping movie url 348/362 --------------------
# https://www.imdb.com/title/tt0126886/plotsummary
# -------------------- Scraping movie url 349/362 --------------------
# https://www.imdb.com/title/tt1322269/plotsummary
# -------------------- Scraping movie url 350/362 --------------------
# https://www.imdb.com/title/tt0080009/plotsummary
# -------------------- Scraping movie url 351/362 --------------------
# https://www.imdb.com/title/tt0083722/plotsummary
# -------------------- Scraping movie url 352/362 --------------------
# https://www.imdb.com/title/tt1596350/plotsummary
# -------------------- Scraping movie url 353/362 --------------------
# https://www.imdb.com/title/tt0144084/plotsummary
# -------------------- Scraping movie url 354/362 --------------------
# https://www.imdb.com/title/tt0115736/plotsummary
# -------------------- Scraping movie url 355/362 --------------------
# https://www.imdb.com/title/tt0114436/plotsummary
# -------------------- Scraping movie url 356/362 --------------------
# https://www.imdb.com/title/tt0172493/plotsummary
# -------------------- Scraping movie url 357/362 --------------------
# https://www.imdb.com/title/tt0120738/plotsummary
# -------------------- Scraping movie url 358/362 --------------------
# https://www.imdb.com/title/tt0109040/plotsummary
# -------------------- Scraping movie url 359/362 --------------------
# https://www.imdb.com/title/tt0115963/plotsummary
# -------------------- Scraping movie url 360/362 --------------------
# https://www.imdb.com/title/tt0102926/plotsummary
# -------------------- Scraping movie url 361/362 --------------------
# https://www.imdb.com/title/tt0145531/plotsummary
# -------------------- Scraping movie url 362/362 --------------------
# https://www.imdb.com/title/tt0117571/plotsummary

# %% [markdown]
# # Cocatenate movies for an actor and store as a single document

# %%
for i in range(len(actors)):
    fl_1 = actors['nconst'][i]
    #dataAct=actors['primaryName'][i]+':\n'
    dataAct=actors['nconst'][i]+':\n'
    for fl_2 in actors['knownForTitles'][i].split(','):
        fl_2 = 'movieFile/'+fl_2+'.txt'
        with open(fl_2, 'r') as file:
            data = file.read().replace('\n \n', '')
            dataAct = dataAct+'\n'+data
    act_file = 'actorFile/'+fl_1+'.txt'
    write_lst(dataAct,act_file)

# %%
actors.to_csv('actors.csv',header=True,index=False)
actors.head()
# Out:
#       nconst       primaryName birthYear deathYear  \
# 0  nm0000084           Gong Li      1965        \N
# 1  nm0000093         Brad Pitt      1963        \N
# 2  nm0000096  Gillian Anderson      1968        \N
# 3  nm0000097   Pamela Anderson      1967        \N
# 4  nm0000098  Jennifer Aniston      1969        \N
#
#              primaryProfession                           knownForTitles  \
# 0                      actress  tt0101640,tt0430357,tt0397535,tt0473444
# 1    actor,producer,soundtrack  tt0114746,tt1210166,tt0356910,tt2935510
# 2  actress,producer,soundtrack  tt0106179,tt2294189,tt0455590,tt0442632
# 3    actress,producer,director  tt0115624,tt0267913,tt0306047,tt0426592
# 4  actress,producer,soundtrack  tt1723121,tt0279113,tt0108778,tt3442006
#
#    titleCount
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
